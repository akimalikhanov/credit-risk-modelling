# %% [markdown]
# # Hyperparameter Optimization

# %% [markdown]
# This is the last notebook of this project. Here I'll try to squeeze a little more AUC from LightGBM by tweaking its hyperparameters. I'll use Bayesian Search here, as it usually performs better than Random or Grid Search.

# %%
from functools import partial
from sklearn import ensemble, metrics, model_selection
from hyperopt import hp, fmin, tpe, Trials, STATUS_OK
from hyperopt.pyll.base import scope
from timeit import default_timer as timer
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.compose import ColumnTransformer
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 150)
pd.set_option('display.float_format', lambda x: '%.5f' % x)
sns.set()
import warnings
warnings.filterwarnings(action='ignore')
import gc
from imports import *

# %%
df=pd.read_csv('../data/train_fs.csv')
df=convert_types(df)
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER    AMT_CREDIT  \
# 0      100002    True         Cash loans           M  406597.50000
# 1      100003   False         Cash loans           F 1293502.50000
# 2      100004   False    Revolving loans           M  135000.00000
# 3      100006   False         Cash loans           F  312682.50000
# 4      100007   False         Cash loans           M  513000.00000
#
#    AMT_ANNUITY NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0  24700.50000          Working  Secondary / secondary special
# 1  35698.50000    State servant               Higher education
# 2   6750.00000          Working  Secondary / secondary special
# 3  29686.50000          Working  Secondary / secondary special
# 4  21865.50000          Working  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  REGION_POPULATION_RELATIVE  \
# 0  Single / not married  House / apartment                     0.01880
# 1               Married  House / apartment                     0.00354
# 2  Single / not married  House / apartment                     0.01003
# 3        Civil marriage  House / apartment                     0.00802
# 4  Single / not married  House / apartment                     0.02866
#
#    DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  DAYS_ID_PUBLISH  OWN_CAR_AGE  \
# 0       -9461           -637        -3648.00000            -2120          NaN
# 1      -16765          -1188        -1186.00000             -291          NaN
# 2      -19046           -225        -4260.00000            -2531     26.00000
# 3      -19005          -3039        -9833.00000            -2437          NaN
# 4      -19932          -3038        -4311.00000            -3458          NaN
#
#   OCCUPATION_TYPE  REGION_RATING_CLIENT WEEKDAY_APPR_PROCESS_START  \
# 0        Laborers                     2                  WEDNESDAY
# 1      Core staff                     1                     MONDAY
# 2        Laborers                     2                     MONDAY
# 3        Laborers                     2                  WEDNESDAY
# 4      Core staff                     2                   THURSDAY
#
#    HOUR_APPR_PROCESS_START  REG_CITY_NOT_LIVE_CITY       ORGANIZATION_TYPE  \
# 0                       10                       0  Business Entity Type 3
# 1                       11                       0                  School
# 2                        9                       0              Government
# 3                       17                       0  Business Entity Type 3
# 4                       11                       0                Religion
#
#    EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  APARTMENTS_AVG  BASEMENTAREA_AVG  \
# 0       0.08304       0.26295       0.13938         0.02470           0.03690
# 1       0.31127       0.62225           NaN         0.09590           0.05290
# 2           NaN       0.55591       0.72957             NaN               NaN
# 3           NaN       0.65044           NaN             NaN               NaN
# 4           NaN       0.32274           NaN             NaN               NaN
#
#    YEARS_BEGINEXPLUATATION_AVG  YEARS_BUILD_AVG  COMMONAREA_AVG  \
# 0                      0.97220          0.61920         0.01430
# 1                      0.98510          0.79600         0.06050
# 2                          NaN              NaN             NaN
# 3                          NaN              NaN             NaN
# 4                          NaN              NaN             NaN
#
#    ENTRANCES_AVG  FLOORSMAX_AVG  FLOORSMIN_AVG  LANDAREA_AVG  \
# 0        0.06900        0.08330        0.12500       0.03690
# 1        0.03450        0.29170        0.33330       0.01300
# 2            NaN            NaN            NaN           NaN
# 3            NaN            NaN            NaN           NaN
# 4            NaN            NaN            NaN           NaN
#
#    NONLIVINGAREA_AVG WALLSMATERIAL_MODE  DEF_30_CNT_SOCIAL_CIRCLE  \
# 0            0.00000       Stone, brick                   2.00000
# 1            0.00980              Block                   0.00000
# 2                NaN                NaN                   0.00000
# 3                NaN                NaN                   0.00000
# 4                NaN                NaN                   0.00000
#
#    DEF_60_CNT_SOCIAL_CIRCLE  DAYS_LAST_PHONE_CHANGE  FLAG_DOCUMENT_3  \
# 0                   2.00000             -1134.00000             True
# 1                   0.00000              -828.00000             True
# 2                   0.00000              -815.00000            False
# 3                   0.00000              -617.00000             True
# 4                   0.00000             -1106.00000            False
#
#    FLAG_DOCUMENT_16  FLAG_DOCUMENT_18  AMT_REQ_CREDIT_BUREAU_YEAR  \
# 0                 0                 0                     1.00000
# 1                 0                 0                     0.00000
# 2                 0                 0                     0.00000
# 3                 0                 0                         NaN
# 4                 0                 0                     0.00000
#
#    previous_CHANNEL_TYPE_Channelofcorporatesales_mean  \
# 0                                            0.00000
# 1                                            0.00000
# 2                                            0.00000
# 3                                            0.00000
# 4                                            0.00000
#
#    previous_CODE_REJECT_REASON_HC_mean  \
# 0                              0.00000
# 1                              0.00000
# 2                              0.00000
# 3                              0.00000
# 4                              0.00000
#
#    previous_PRODUCT_COMBINATION_CashStreetlow_mean  \
# 0                                          0.00000
# 1                                          0.00000
# 2                                          0.00000
# 3                                          0.00000
# 4                                          0.00000
#
#    previous_NAME_YIELD_GROUP_low_action_mean  \
# 0                                    0.00000
# 1                                    0.00000
# 2                                    0.00000
# 3                                    0.00000
# 4                                    0.00000
#
#    previous_PRODUCT_COMBINATION_CashStreethigh_mean  \
# 0                                           0.00000
# 1                                           0.00000
# 2                                           0.00000
# 3                                           0.00000
# 4                                           0.16667
#
#    previous_CHANNEL_TYPE_APCashloan_mean  \
# 0                                0.00000
# 1                                0.00000
# 2                                0.00000
# 3                                0.00000
# 4                                0.16667
#
#    previous_NAME_PRODUCT_TYPE_walkin_mean  \
# 0                                 0.00000
# 1                                 0.00000
# 2                                 0.00000
# 3                                 0.00000
# 4                                 0.16667
#
#    previous_WEEKDAY_APPR_PROCESS_START_MONDAY_mean  \
# 0                                          0.00000
# 1                                          0.00000
# 2                                          0.00000
# 3                                          0.00000
# 4                                          0.16667
#
#    previous_PRODUCT_COMBINATION_CashXSellhigh_mean  \
# 0                                          0.00000
# 1                                          0.00000
# 2                                          0.00000
# 3                                          0.11111
# 4                                          0.00000
#
#    previous_NAME_CONTRACT_STATUS_Refused_mean  \
# 0                                     0.00000
# 1                                     0.00000
# 2                                     0.00000
# 3                                     0.11111
# 4                                     0.00000
#
#    previous_NAME_GOODS_CATEGORY_Furniture_mean  \
# 0                                      0.00000
# 1                                      0.33333
# 2                                      0.00000
# 3                                      0.00000
# 4                                      0.00000
#
#    previous_NAME_SELLER_INDUSTRY_Furniture_mean  \
# 0                                       0.00000
# 1                                       0.33333
# 2                                       0.00000
# 3                                       0.00000
# 4                                       0.00000
#
#    previous_PRODUCT_COMBINATION_POSindustrywithinterest_mean  \
# 0                                            0.00000
# 1                                            0.33333
# 2                                            0.00000
# 3                                            0.11111
# 4                                            0.00000
#
#    previous_PRODUCT_COMBINATION_CashXSelllow_mean  \
# 0                                         0.00000
# 1                                         0.33333
# 2                                         0.00000
# 3                                         0.22222
# 4                                         0.00000
#
#    previous_NAME_SELLER_INDUSTRY_XNA_mean  \
# 0                                 0.00000
# 1                                 0.33333
# 2                                 0.00000
# 3                                 0.77778
# 4                                 0.33333
#
#    previous_NAME_TYPE_SUITE_Unaccompanied_mean  \
# 0                                      0.00000
# 1                                      0.33333
# 2                                      1.00000
# 3                                      0.33333
# 4                                      0.33333
#
#    previous_NAME_YIELD_GROUP_middle_mean  previous_NAME_CLIENT_TYPE_New_mean  \
# 0                                0.00000                             1.00000
# 1                                0.66667                             0.00000
# 2                                1.00000                             1.00000
# 3                                0.11111                             0.11111
# 4                                0.50000                             0.16667
#
#    previous_NAME_YIELD_GROUP_low_normal_mean  \
# 0                                    1.00000
# 1                                    0.33333
# 2                                    0.00000
# 3                                    0.22222
# 4                                    0.00000
#
#    previous_NAME_PAYMENT_TYPE_XNA_mean  previous_NAME_YIELD_GROUP_high_mean  \
# 0                              1.00000                              0.00000
# 1                              0.33333                              0.00000
# 2                              0.00000                              0.00000
# 3                              0.55556                              0.22222
# 4                              0.16667                              0.50000
#
#    previous_NAME_YIELD_GROUP_high_sum  \
# 0                             0.00000
# 1                             0.00000
# 2                             0.00000
# 3                             2.00000
# 4                             3.00000
#
#    previous_NAME_CLIENT_TYPE_Refreshed_mean  \
# 0                                   0.00000
# 1                                   0.66667
# 2                                   0.00000
# 3                                   0.00000
# 4                                   0.00000
#
#    previous_NAME_TYPE_SUITE_Family_mean  previous_NAME_PRODUCT_TYPE_XNA_mean  \
# 0                               0.00000                              1.00000
# 1                               0.66667                              0.66667
# 2                               0.00000                              1.00000
# 3                               0.11111                              0.55556
# 4                               0.33333                              0.33333
#
#    previous_NAME_CONTRACT_STATUS_Approved_mean  previous_DAYS_DECISION_sum  \
# 0                                      1.00000                  -606.00000
# 1                                      1.00000                 -3915.00000
# 2                                      1.00000                  -815.00000
# 3                                      0.55556                 -2452.00000
# 4                                      1.00000                 -7337.00000
#
#    previous_DAYS_DECISION_min  previous_DAYS_DECISION_mean  \
# 0                  -606.00000                   -606.00000
# 1                 -2341.00000                  -1305.00000
# 2                  -815.00000                   -815.00000
# 3                  -617.00000                   -272.44446
# 4                 -2357.00000                  -1222.83337
#
#    previous_DAYS_DECISION_max  previous_DAYS_FIRST_DUE_sum  \
# 0                  -606.00000                   -565.00000
# 1                  -746.00000                  -3823.00000
# 2                  -815.00000                   -784.00000
# 3                  -181.00000                 364266.00000
# 4                  -374.00000                  -6316.00000
#
#    previous_DAYS_FIRST_DUE_min  previous_DAYS_FIRST_DUE_mean  \
# 0                   -565.00000                    -565.00000
# 1                  -2310.00000                   -1274.33337
# 2                   -784.00000                    -784.00000
# 3                   -545.00000                   91066.50000
# 4                  -2326.00000                   -1263.19995
#
#    previous_DAYS_LAST_DUE_sum  previous_DAYS_LAST_DUE_min  \
# 0                   -25.00000                   -25.00000
# 1                 -3163.00000                 -1980.00000
# 2                  -724.00000                  -724.00000
# 3                729910.00000                  -425.00000
# 4                360681.00000                 -2056.00000
#
#    previous_DAYS_LAST_DUE_mean  previous_DAYS_LAST_DUE_max  \
# 0                    -25.00000                   -25.00000
# 1                  -1054.33337                  -536.00000
# 2                   -724.00000                  -724.00000
# 3                 182477.50000                365243.00000
# 4                  72136.20312                365243.00000
#
#    previous_DAYS_LAST_DUE_1ST_VERSION_sum  \
# 0                               125.00000
# 1                             -3013.00000
# 2                              -694.00000
# 3                            366336.00000
# 4                             -4186.00000
#
#    previous_DAYS_LAST_DUE_1ST_VERSION_min  \
# 0                               125.00000
# 1                             -1980.00000
# 2                              -694.00000
# 3                              -215.00000
# 4                             -2056.00000
#
#    previous_DAYS_LAST_DUE_1ST_VERSION_mean  \
# 0                                125.00000
# 1                              -1004.33331
# 2                               -694.00000
# 3                              91584.00000
# 4                               -837.20001
#
#    previous_NFLAG_INSURED_ON_APPROVAL_mean  previous_RATE_DOWN_PAYMENT_min  \
# 0                                  0.00000                         0.00000
# 1                                  0.66667                         0.00000
# 2                                  0.00000                         0.21201
# 3                                  0.00000                         0.10899
# 4                                  0.60000                         0.10014
#
#    previous_RATE_DOWN_PAYMENT_mean  previous_RATE_DOWN_PAYMENT_max  \
# 0                          0.00000                         0.00000
# 1                          0.05003                         0.10006
# 2                          0.21201                         0.21201
# 3                          0.16341                         0.21783
# 4                          0.15952                         0.21889
#
#    previous_RATE_DOWN_PAYMENT_sum  previous_CNT_PAYMENT_mean  \
# 0                         0.00000                   24.00000
# 1                         0.10006                   10.00000
# 2                         0.21201                    4.00000
# 3                         0.32682                   23.00000
# 4                         0.31903                   20.66667
#
#    previous_CNT_PAYMENT_max  previous_CNT_PAYMENT_sum  \
# 0                  24.00000                  24.00000
# 1                  12.00000                  30.00000
# 2                   4.00000                   4.00000
# 3                  48.00000                 138.00000
# 4                  48.00000                 124.00000
#
#    previous_HOUR_APPR_PROCESS_START_mean  \
# 0                                9.00000
# 1                               14.66667
# 2                                5.00000
# 3                               14.66667
# 4                               12.33333
#
#    previous_HOUR_APPR_PROCESS_START_max  previous_AMT_DOWN_PAYMENT_mean  \
# 0                               9.00000                         0.00000
# 1                              17.00000                      3442.50000
# 2                               5.00000                      4860.00000
# 3                              15.00000                     34840.17188
# 4                              15.00000                      3390.75000
#
#    previous_AMT_DOWN_PAYMENT_max  previous_AMT_ANNUITY_min  \
# 0                        0.00000                9251.77539
# 1                     6885.00000                6737.31006
# 2                     4860.00000                5357.25000
# 3                    66987.00000                2482.91992
# 4                     3676.50000                1834.29004
#
#    previous_AMT_ANNUITY_mean  previous_AMT_ANNUITY_max  \
# 0                 9251.77539                9251.77539
# 1                56553.98828               98356.99219
# 2                 5357.25000                5357.25000
# 3                23651.17578               39954.51172
# 4                12278.80469               22678.78516
#
#    previous_AMT_ANNUITY_sum  previous_AMT_CREDIT_mean  \
# 0                9251.77539              179055.00000
# 1              169661.96875              484191.00000
# 2                5357.25000               20106.00000
# 3              141907.04688              291695.50000
# 4               73672.82812              166638.75000
#
#    previous_AMT_CREDIT_max  previous_AMT_GOODS_PRICE_min  \
# 0             179055.00000                  179055.00000
# 1            1035882.00000                   68809.50000
# 2              20106.00000                   24282.00000
# 3             906615.00000                   26912.33984
# 4             284400.00000                   17176.50000
#
#    previous_DAYS_FIRST_DRAWING_mean  client_cash_MONTHS_BALANCE_sum_sum  \
# 0                      365243.00000                         -3610.00000
# 1                      365243.00000                        -13240.00000
# 2                      365243.00000                          -408.00000
# 3                      365243.00000                         -1651.00000
# 4                      365243.00000                        -28362.00000
#
#    client_cash_MONTHS_BALANCE_min_sum  client_cash_MONTHS_BALANCE_sum_min  \
# 0                          -361.00000                          -190.00000
# 1                         -1348.00000                          -858.00000
# 2                          -108.00000                          -102.00000
# 3                          -278.00000                          -132.00000
# 4                         -2640.00000                          -725.00000
#
#    client_cash_MONTHS_BALANCE_sum_max  client_cash_MONTHS_BALANCE_min_mean  \
# 0                          -190.00000                            -19.00000
# 1                          -172.00000                            -48.14286
# 2                          -102.00000                            -27.00000
# 3                           -15.00000                            -13.23810
# 4                           -78.00000                            -40.00000
#
#    client_cash_MONTHS_BALANCE_min_max  client_cash_SK_DPD_mean_min  \
# 0                           -19.00000                      0.00000
# 1                           -25.00000                      0.00000
# 2                           -27.00000                      0.00000
# 3                            -6.00000                      0.00000
# 4                           -12.00000                      0.00000
#
#    client_cash_CNT_INSTALMENT_FUTURE_min_mean  \
# 0                                     6.00000
# 1                                     0.42857
# 2                                     0.00000
# 3                                     1.42857
# 4                                     2.51515
#
#    client_cash_CNT_INSTALMENT_FUTURE_min_max  \
# 0                                    6.00000
# 1                                    1.00000
# 2                                    0.00000
# 3                                    3.00000
# 4                                   13.00000
#
#    client_cash_CNT_INSTALMENT_FUTURE_min_sum  \
# 0                                  114.00000
# 1                                   12.00000
# 2                                    0.00000
# 3                                   30.00000
# 4                                  166.00000
#
#    client_cash_NAME_CONTRACT_STATUS_Completed_mean_mean  \
# 0                                            0.00000
# 1                                            0.07143
# 2                                            0.25000
# 3                                            0.09524
# 4                                            0.04545
#
#    client_cash_CNT_INSTALMENT_FUTURE_mean_min  \
# 0                                    15.00000
# 1                                     2.62500
# 2                                     2.25000
# 3                                     7.14286
# 4                                     5.50000
#
#    client_cash_SK_DPD_DEF_mean_mean  client_cash_SK_DPD_mean_mean  \
# 0                           0.00000                       0.00000
# 1                           0.00000                       0.00000
# 2                           0.00000                       0.00000
# 3                           0.00000                       0.00000
# 4                           0.00000                       0.00000
#
#    client_cash_NAME_CONTRACT_STATUS_Active_mean_mean  \
# 0                                            1.00000
# 1                                            0.92857
# 2                                            0.75000
# 3                                            0.85714
# 4                                            0.93939
#
#    client_cash_NAME_CONTRACT_STATUS_Completed_sum_mean  \
# 0                                            0.00000
# 1                                            0.57143
# 2                                            1.00000
# 3                                            0.52381
# 4                                            0.66667
#
#    client_cash_CNT_INSTALMENT_FUTURE_mean_mean  \
# 0                                     15.00000
# 1                                      5.78571
# 2                                      2.25000
# 3                                      8.57823
# 4                                      8.96970
#
#    client_cash_CNT_INSTALMENT_FUTURE_mean_max  \
# 0                                    15.00000
# 1                                     7.87500
# 2                                     2.25000
# 3                                    16.00000
# 4                                    18.50000
#
#    client_cash_CNT_INSTALMENT_FUTURE_sum_min  \
# 0                                  285.00000
# 1                                   21.00000
# 2                                    9.00000
# 3                                   48.00000
# 4                                   55.00000
#
#    client_cash_NAME_CONTRACT_STATUS_Active_sum_mean  \
# 0                                          19.00000
# 1                                           9.14286
# 2                                           3.00000
# 3                                           7.33333
# 4                                          12.86364
#
#    client_cash_CNT_INSTALMENT_min_mean  \
# 0                             24.00000
# 1                              8.85714
# 2                              3.00000
# 3                              7.76190
# 4                             15.24242
#
#    client_cash_NAME_CONTRACT_STATUS_Active_mean_sum  \
# 0                                          19.00000
# 1                                          26.00000
# 2                                           3.00000
# 3                                          18.00000
# 4                                          62.00000
#
#    client_cash_CNT_INSTALMENT_FUTURE_mean_sum  \
# 0                                   285.00000
# 1                                   162.00000
# 2                                     9.00000
# 3                                   180.14285
# 4                                   592.00000
#
#    client_cash_NAME_CONTRACT_STATUS_Active_sum_sum  \
# 0                                        361.00000
# 1                                        256.00000
# 2                                         12.00000
# 3                                        154.00000
# 4                                        849.00000
#
#    client_credit_MONTHS_BALANCE_sum_sum  client_credit_AMT_RECIVABLE_min_min  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                            -126.00000                              0.00000
# 4                                   NaN                                  NaN
#
#    client_credit_AMT_DRAWINGS_POS_CURRENT_sum_min  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                         0.00000
# 4                                             NaN
#
#    client_credit_AMT_DRAWINGS_POS_CURRENT_sum_sum  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                         0.00000
# 4                                             NaN
#
#    client_credit_CNT_DRAWINGS_CURRENT_mean_min  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                      0.00000
# 4                                          NaN
#
#    client_credit_CNT_DRAWINGS_CURRENT_max_min  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                     0.00000
# 4                                         NaN
#
#    client_credit_CNT_DRAWINGS_ATM_CURRENT_sum_min  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                         0.00000
# 4                                             NaN
#
#    client_credit_CNT_INSTALMENT_MATURE_CUM_mean_min  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                           0.00000
# 4                                               NaN
#
#    client_credit_AMT_DRAWINGS_CURRENT_mean_min  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                      0.00000
# 4                                          NaN
#
#    client_credit_AMT_INST_MIN_REGULARITY_mean_min  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                         0.00000
# 4                                             NaN
#
#    client_credit_AMT_INST_MIN_REGULARITY_max_min  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                        0.00000
# 4                                            NaN
#
#    client_credit_AMT_DRAWINGS_ATM_CURRENT_sum_min  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                         0.00000
# 4                                             NaN
#
#    client_credit_AMT_PAYMENT_TOTAL_CURRENT_max_sum  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                          0.00000
# 4                                              NaN
#
#    client_credit_AMT_CREDIT_LIMIT_ACTUAL_mean_min  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                    270000.00000
# 4                                             NaN
#
#    client_credit_AMT_CREDIT_LIMIT_ACTUAL_sum_sum  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                  9720000.00000
# 4                                            NaN
#
#    client_installments_DAYS_ENTRY_PAYMENT_sum_sum  \
# 0                                   -113867.00000
# 1                                   -367137.00000
# 2                                     -6855.00000
# 3                                    -28559.00000
# 4                                   -880686.00000
#
#    client_installments_DAYS_ENTRY_PAYMENT_sum_max  \
# 0                                     -5993.00000
# 1                                     -4399.00000
# 2                                     -2285.00000
# 3                                      -174.00000
# 4                                     -2175.00000
#
#    client_installments_DAYS_ENTRY_PAYMENT_min_mean  \
# 0                                       -587.00000
# 1                                      -1510.28003
# 2                                       -795.00000
# 3                                       -368.68750
# 4                                      -1217.69702
#
#    client_installments_NUM_INSTALMENT_VERSION_mean_mean  \
# 0                                            1.05263
# 1                                            1.04000
# 2                                            1.33333
# 3                                            1.12500
# 4                                            1.16667
#
#    client_installments_NUM_INSTALMENT_VERSION_mean_max  \
# 0                                            1.05263
# 1                                            1.14286
# 2                                            1.33333
# 3                                            2.00000
# 4                                            1.64706
#
#    client_installments_NUM_INSTALMENT_NUMBER_min_mean  \
# 0                                            1.00000
# 1                                            1.00000
# 2                                            1.00000
# 3                                            1.00000
# 4                                            1.00000
#
#    client_installments_NUM_INSTALMENT_VERSION_sum_mean  \
# 0                                           20.00000
# 1                                            9.44000
# 2                                            4.00000
# 3                                            8.25000
# 4                                           16.43939
#
#    client_installments_NUM_INSTALMENT_VERSION_sum_max  \
# 0                                           20.00000
# 1                                           12.00000
# 2                                            4.00000
# 3                                           10.00000
# 4                                           28.00000
#
#    client_installments_NUM_INSTALMENT_VERSION_mean_sum  \
# 0                                           20.00000
# 1                                           26.00000
# 2                                            4.00000
# 3                                           18.00000
# 4                                           77.00000
#
#    client_installments_NUM_INSTALMENT_VERSION_sum_sum  \
# 0                                          380.00000
# 1                                          236.00000
# 2                                           12.00000
# 3                                          132.00000
# 4                                         1085.00000
#
#    client_installments_AMT_PAYMENT_min_max  \
# 0                               9251.77539
# 1                              98356.99219
# 2                               5357.25000
# 3                             691786.87500
# 4                              16046.09961
#
#    client_installments_AMT_PAYMENT_mean_min  \
# 0                               11559.24707
# 1                                6731.11523
# 2                                7096.15479
# 3                                5018.26465
# 4                                1833.03906
#
#    client_installments_AMT_INSTALMENT_max_min  \
# 0                                 53093.74609
# 1                                  6737.31006
# 2                                 10573.96484
# 3                                 15159.64453
# 4                                  1834.29004
#
#    client_installments_AMT_PAYMENT_mean_mean  \
# 0                                11559.24707
# 1                                64754.58594
# 2                                 7096.15479
# 3                                62947.08594
# 4                                12214.05957
#
#    client_installments_AMT_PAYMENT_mean_max  \
# 0                               11559.24707
# 1                              164425.32812
# 2                                7096.15479
# 3                              691786.87500
# 4                               20919.41016
#
#    client_installments_AMT_INSTALMENT_max_mean  \
# 0                                  53093.74609
# 1                                 175764.04688
# 2                                  10573.96484
# 3                                  66116.26562
# 4                                  12677.32422
#
#    client_installments_AMT_PAYMENT_sum_min  \
# 0                             219625.70312
# 1                              80773.38281
# 2                              21288.46484
# 3                              25091.32422
# 4                              18330.39062
#
#    client_installments_AMT_INSTALMENT_max_max  \
# 0                                 53093.74609
# 1                                560835.37500
# 2                                 10573.96484
# 3                                691786.87500
# 4                                 22678.78516
#
#    client_installments_AMT_PAYMENT_sum_mean  \
# 0                              219625.70312
# 1                              453952.21875
# 2                               21288.46484
# 3                              232499.70312
# 4                              172669.89062
#
#    client_installments_AMT_PAYMENT_min_sum  \
# 0                             175783.73438
# 1                            1154108.25000
# 2                              16071.75000
# 3                             994476.68750
# 4                             483756.37500
#
#    client_installments_AMT_INSTALMENT_min_sum  \
# 0                                175783.73438
# 1                               1154108.25000
# 2                                 16071.75000
# 3                                994476.68750
# 4                                825845.81250
#
#    client_installments_AMT_PAYMENT_sum_max  \
# 0                             219625.70312
# 1                            1150977.37500
# 2                              21288.46484
# 3                             691786.87500
# 4                             280199.68750
#
#    client_installments_AMT_PAYMENT_mean_sum  \
# 0                              219625.68750
# 1                             1618864.62500
# 2                               21288.46484
# 3                             1007153.37500
# 4                              806127.93750
#
#    client_installments_AMT_INSTALMENT_max_sum  \
# 0                               1008781.18750
# 1                               4394101.50000
# 2                                 31721.89453
# 3                               1057860.25000
# 4                                836703.37500
#
#    client_installments_AMT_PAYMENT_sum_sum
# 0                            4172888.25000
# 1                           11348806.00000
# 2                              63865.39453
# 3                            3719995.25000
# 4                           11396213.00000

# %%
def optimize(params, x, y, k=5):
    global ITERATION
    ITERATION += 1
    aucs_test=[]
    subsample = params['boosting_type'].get('subsample', 1.0)
    params['boosting_type'] = params['boosting_type']['boosting_type']
    params['subsample'] = subsample
    params['metrics']='auc'
    params['verbose']=-1
    for p in ['num_leaves', 'max_depth', 'min_child_samples']:
        params[p] = int(params[p])

    start = timer()
    kfold=StratifiedKFold(k)
    for f, (tr, te) in enumerate(kfold.split(x, y=y)):
        X_train, y_train=x.iloc[tr, :], y.iloc[tr]
        X_test, y_test=x.iloc[te, :], y.iloc[te]

        params=params
        dtrain=lgb.Dataset(X_train, label=y_train)
        dval=lgb.Dataset(X_test, label=y_test)
   
        model=lgb.train(
                params=params,
                train_set=dtrain,
                valid_sets=[dtrain, dval],
                valid_names=['train', 'test'],
                callbacks=[lgb.early_stopping(100, verbose=-100), lgb.log_evaluation(-100)],
                categorical_feature=list(x.select_dtypes(include=['category', 'object']).columns),
                verbose_eval=False)
        
        aucs_test.append(model.best_score['test']['auc'])

    run_time = timer() - start
    
    auc_mean=np.mean(aucs_test)
    return {'loss': 1-auc_mean, 'auc': auc_mean, 'params': params, 'iteration': ITERATION,
                'train_time': run_time, 'status': STATUS_OK}

# %%
df_sample=df.sample(frac=.3)

# %%
X, y=df.drop(['TARGET'], axis=1), df['TARGET'].astype(int)

param_space = {
    'boosting_type': hp.choice('boosting_type', 
                    [{'boosting_type': 'gbdt', 'subsample': hp.uniform('gdbt_subsample', 0.6, 1)}, 
                     {'boosting_type': 'dart', 'subsample': hp.uniform('dart_subsample', 0.6, 1)},
                     {'boosting_type': 'goss', 'subsample': 1.0}]),
    'num_leaves': hp.quniform('num_leaves', 20, 150, 1),
    'learning_rate': hp.loguniform('learning_rate', np.log(0.01), np.log(0.3)),
    'max_depth': hp.quniform('max_depth', 3, 18, 2),
    'min_child_samples': hp.quniform('min_child_samples', 20, 500, 5),
    'reg_alpha': hp.uniform('reg_alpha', 0.0, 1.0),
    'reg_lambda': hp.uniform('reg_lambda', 0.0, 1.0),
    'colsample_bytree': hp.uniform('colsample_by_tree', 0.6, 1.0),
    'is_unbalance': hp.choice('is_unbalance', [True, False]),
}

# t=Trials()
ITERATION, MAX_EVALS=252, 280

hopt=fmin(
    fn=partial(optimize, x=X, y=y),
    space=param_space,
    algo=tpe.suggest,
    max_evals=MAX_EVALS,
    trials=t
)

hopt
# Out:
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.815374	test's auc: 0.768914
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.815345	test's auc: 0.76928
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.815997	test's auc: 0.762156
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.815553	test's auc: 0.769152
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.815109	test's auc: 0.76981
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.835692	test's auc: 0.772995
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.835254	test's auc: 0.773772
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.836659	test's auc: 0.768228
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.83637	test's auc: 0.774397
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.835817	test's auc: 0.775707
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.842132	test's auc: 0.772616
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.842448	test's auc: 0.771903
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.841097	test's auc: 0.766074
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.841803	test's auc: 0.773248
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.840576	test's auc: 0.775646
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.817754	test's auc: 0.771179
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.81781	test's auc: 0.773316
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.81863	test's auc: 0.766097
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.81825	test's auc: 0.769974
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.818363	test's auc: 0.770853
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.890815	test's auc: 0.765943
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.889932	test's auc: 0.767413
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.893027	test's auc: 0.758953
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.891565	test's auc: 0.76419
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.892223	test's auc: 0.768557
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.820508	test's auc: 0.772711
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.821287	test's auc: 0.773033
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.822485	test's auc: 0.767034
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.821136	test's auc: 0.772675
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.821237	test's auc: 0.773671
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.844824	test's auc: 0.772699
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.844561	test's auc: 0.773883
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.845636	test's auc: 0.768549
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.84506	test's auc: 0.772427
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.845204	test's auc: 0.775647
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.852952	test's auc: 0.774012
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.852355	test's auc: 0.773707
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.852421	test's auc: 0.767762
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.852986	test's auc: 0.772586
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.851586	test's auc: 0.774992
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.839549	test's auc: 0.774238
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.839601	test's auc: 0.7741
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.840447	test's auc: 0.769051
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.840678	test's auc: 0.7718
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.837768	test's auc: 0.775534
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.834703	test's auc: 0.773384
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.834432	test's auc: 0.774024
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.8355	test's auc: 0.767977
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.834715	test's auc: 0.772555
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.833913	test's auc: 0.773949
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.84715	test's auc: 0.773147
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.846919	test's auc: 0.775479
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.847095	test's auc: 0.76704
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.848011	test's auc: 0.773523
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.846341	test's auc: 0.773978
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.834918	test's auc: 0.773402
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.83539	test's auc: 0.774939
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.836288	test's auc: 0.768399
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.836429	test's auc: 0.773674
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.835186	test's auc: 0.775294
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.8289	test's auc: 0.773457
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.829375	test's auc: 0.77442
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.830643	test's auc: 0.768658
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.830509	test's auc: 0.773304
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.829157	test's auc: 0.774631
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.83237	test's auc: 0.774295
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.83226	test's auc: 0.774321
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.833103	test's auc: 0.769616
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.833034	test's auc: 0.773162
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.831773	test's auc: 0.774045
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.815565	test's auc: 0.771545
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.815439	test's auc: 0.771639
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.816426	test's auc: 0.764728
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.816361	test's auc: 0.770986
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.815683	test's auc: 0.772682
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.819312	test's auc: 0.772729
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.819418	test's auc: 0.772306
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.820544	test's auc: 0.765535
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.819429	test's auc: 0.771786
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.818954	test's auc: 0.773369
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.826152	test's auc: 0.773773
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.827193	test's auc: 0.773142
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.828911	test's auc: 0.768222
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.828402	test's auc: 0.772446
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.826509	test's auc: 0.774998
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.82358	test's auc: 0.772966
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.822965	test's auc: 0.773455
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.824256	test's auc: 0.76752
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.82423	test's auc: 0.773623
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.823791	test's auc: 0.774131
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.807919	test's auc: 0.769721
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.807746	test's auc: 0.768932
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.808552	test's auc: 0.761892
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.808215	test's auc: 0.769576
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.807616	test's auc: 0.771141
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.833378	test's auc: 0.77269
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.833176	test's auc: 0.775092
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.83403	test's auc: 0.768584
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.83412	test's auc: 0.773496
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.833276	test's auc: 0.774395
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.8184	test's auc: 0.77093
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.818147	test's auc: 0.771879
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.819428	test's auc: 0.765211
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.818993	test's auc: 0.771904
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.818497	test's auc: 0.77178
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.816598	test's auc: 0.77264
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.816188	test's auc: 0.772291
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.817198	test's auc: 0.767555
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.817719	test's auc: 0.772982
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.815696	test's auc: 0.773151
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.813446	test's auc: 0.771508
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.813691	test's auc: 0.771745
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.814971	test's auc: 0.765184
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.813929	test's auc: 0.771542
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.812981	test's auc: 0.772957
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.83346	test's auc: 0.773889
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.834338	test's auc: 0.772491
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.835198	test's auc: 0.768399
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.833762	test's auc: 0.774081
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.833331	test's auc: 0.77582
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.823308	test's auc: 0.772824
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.823472	test's auc: 0.772935
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.823908	test's auc: 0.767474
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.82342	test's auc: 0.773249
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.823071	test's auc: 0.773884
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.818759	test's auc: 0.771433
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.818842	test's auc: 0.772961
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.819642	test's auc: 0.767099
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.819449	test's auc: 0.773103
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.819027	test's auc: 0.774168
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.837237	test's auc: 0.773749
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.835918	test's auc: 0.773646
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.837821	test's auc: 0.768419
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.837163	test's auc: 0.773515
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.835326	test's auc: 0.775572
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.827801	test's auc: 0.773569
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.826803	test's auc: 0.774679
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.828933	test's auc: 0.768218
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.828088	test's auc: 0.772652
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.826977	test's auc: 0.775177
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.82711	test's auc: 0.772692
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.826032	test's auc: 0.772412
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.827185	test's auc: 0.766978
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.827191	test's auc: 0.770995
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [100]	train's auc: 0.826177	test's auc: 0.773889
# 100%|█████████████████████████████████████████████| 280/280 [32:01<00:00, 64.05s/trial, best loss: 0.22665111993063025]
# {'boosting_type': 2,
#  'colsample_by_tree': 0.8033845649164827,
#  'is_unbalance': 1,
#  'learning_rate': 0.058964080355423776,
#  'max_depth': 12.0,
#  'min_child_samples': 340.0,
#  'num_leaves': 80.0,
#  'reg_alpha': 0.4748405479945878,
#  'reg_lambda': 0.8629344536104161}

# %%
res=pd.DataFrame()
params_list=[exp['params'] for exp in t.results]

for i in ['iteration', 'loss', 'auc']:
    res[i]=[exp[i] for exp in t.results]
    
for n, p in enumerate(params_list):
    for k,v in p.items():
        res.loc[n, k]=v
        
res.sort_values('loss').head(10)
# Out:
#      iteration    loss     auc boosting_type  colsample_bytree is_unbalance  \
# 48          49 0.22665 0.77335          goss           0.80338        False
# 66          67 0.22670 0.77330          goss           0.80564        False
# 262        265 0.22686 0.77314          goss           0.67307         True
# 190        192 0.22690 0.77310          goss           0.62987         True
# 264        267 0.22691 0.77309          goss           0.65100         True
# 88          89 0.22696 0.77304          goss           0.72524         True
# 195        197 0.22696 0.77304          goss           0.63642         True
# 251        254 0.22698 0.77302          goss           0.79533         True
# 220        222 0.22701 0.77299          goss           0.73645         True
# 277        280 0.22702 0.77298          goss           0.61532         True
#
#      learning_rate  max_depth  min_child_samples  num_leaves  reg_alpha  \
# 48         0.05896   12.00000          340.00000    80.00000    0.47484
# 66         0.05812   16.00000          390.00000   106.00000    0.32873
# 262        0.05725   12.00000          340.00000   108.00000    0.74451
# 190        0.05349   12.00000          300.00000   141.00000    0.45215
# 264        0.05160   12.00000          380.00000   115.00000    0.96496
# 88         0.07239   16.00000          285.00000    76.00000    0.17574
# 195        0.06482   12.00000          305.00000   120.00000    0.74245
# 251        0.05913   12.00000          450.00000   122.00000    0.12120
# 220        0.07491   12.00000          285.00000    50.00000    0.99305
# 277        0.06195   12.00000          325.00000   103.00000    0.62107
#
#      reg_lambda  subsample metrics  verbose
# 48      0.86293    1.00000     auc -1.00000
# 66      0.51633    1.00000     auc -1.00000
# 262     0.49608    1.00000     auc -1.00000
# 190     0.50406    1.00000     auc -1.00000
# 264     0.32178    1.00000     auc -1.00000
# 88      0.94538    1.00000     auc -1.00000
# 195     0.50435    1.00000     auc -1.00000
# 251     0.20174    1.00000     auc -1.00000
# 220     0.33337    1.00000     auc -1.00000
# 277     0.51862    1.00000     auc -1.00000

# %%
import json

trials_dict=sorted(t.results, key = lambda x: x['loss'])
with open('../data/trials.bin', 'w') as f:
    f.write(json.dumps(trials_dict))

# %%
fig, axs = plt.subplots(2, 4, figsize = (24, 12))


for c, hyper in enumerate(['colsample_bytree', 'learning_rate', 'min_child_samples', 'num_leaves',
                              'reg_alpha', 'reg_lambda', 'max_depth', 'subsample']):
        sns.regplot(y=hyper, x='iteration', data=res, ax=axs[c//4, c%4])

# %%
t.results
# Out:
# [{'loss': 0.2395270882994801,
#   'auc': 0.7604729117005199,
#   'params': {'boosting_type': 'dart',
#    'colsample_bytree': 0.6247783113860637,
#    'is_unbalance': False,
#    'learning_rate': 0.2876698996815331,
#    'max_depth': 12,
#    'min_child_samples': 405,
#    'num_leaves': 120,
#    'reg_alpha': 0.7498392776468238,
#    'reg_lambda': 0.18946747110284168,
#    'subsample': 0.822834144415607,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 1,
#   'train_time': 92.5742437000008,
#   'status': 'ok'},
#  {'loss': 0.23497803460358013,
#   'auc': 0.7650219653964199,
#   'params': {'boosting_type': 'dart',
#    'colsample_bytree': 0.6638882599830617,
#    'is_unbalance': True,
#    'learning_rate': 0.05272000148128563,
#    'max_depth': 14,
#    'min_child_samples': 475,
#    'num_leaves': 85,
#    'reg_alpha': 0.20453443643899838,
#    'reg_lambda': 0.05803062749011434,
#    'subsample': 0.6857377389521335,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 2,
#   'train_time': 84.38431349999155,
#   'status': 'ok'},
#  {'loss': 0.23064452080715847,
#   'auc': 0.7693554791928415,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.9324991846984527,
#    'is_unbalance': True,
#    'learning_rate': 0.13040166908457665,
#    'max_depth': 8,
#    'min_child_samples': 90,
#    'num_leaves': 33,
#    'reg_alpha': 0.06512500040630964,
#    'reg_lambda': 0.6975369142302306,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 3,
#   'train_time': 51.61621799999557,
#   'status': 'ok'},
#  {'loss': 0.23072962437611122,
#   'auc': 0.7692703756238888,
#   'params': {'boosting_type': 'dart',
#    'colsample_bytree': 0.8692706327240121,
#    'is_unbalance': True,
#    'learning_rate': 0.14052869014475236,
#    'max_depth': 12,
#    'min_child_samples': 265,
#    'num_leaves': 104,
#    'reg_alpha': 0.8287307126191437,
#    'reg_lambda': 0.9277636935141544,
#    'subsample': 0.830697400605666,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 4,
#   'train_time': 100.40531760000158,
#   'status': 'ok'},
#  {'loss': 0.23354315056472996,
#   'auc': 0.76645684943527,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6009969896336332,
#    'is_unbalance': True,
#    'learning_rate': 0.02724870610963348,
#    'max_depth': 12,
#    'min_child_samples': 350,
#    'num_leaves': 66,
#    'reg_alpha': 0.6074156827973956,
#    'reg_lambda': 0.30666630117370797,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 5,
#   'train_time': 60.7291627000086,
#   'status': 'ok'},
#  {'loss': 0.24911559438444375,
#   'auc': 0.7508844056155562,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.8365317969115822,
#    'is_unbalance': True,
#    'learning_rate': 0.012490673296065263,
#    'max_depth': 14,
#    'min_child_samples': 415,
#    'num_leaves': 54,
#    'reg_alpha': 0.04786013353501051,
#    'reg_lambda': 0.10338350552048958,
#    'subsample': 0.6422673334411153,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 6,
#   'train_time': 79.86975189999794,
#   'status': 'ok'},
#  {'loss': 0.2660965328707904,
#   'auc': 0.7339034671292096,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.9321502040681794,
#    'is_unbalance': True,
#    'learning_rate': 0.012039858314960496,
#    'max_depth': 4,
#    'min_child_samples': 255,
#    'num_leaves': 95,
#    'reg_alpha': 0.2501589273322973,
#    'reg_lambda': 0.3480514112009858,
#    'subsample': 0.6475979345371229,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 7,
#   'train_time': 46.74135099998966,
#   'status': 'ok'},
#  {'loss': 0.2340649908842799,
#   'auc': 0.7659350091157201,
#   'params': {'boosting_type': 'dart',
#    'colsample_bytree': 0.7967045112948427,
#    'is_unbalance': False,
#    'learning_rate': 0.10493183115747615,
#    'max_depth': 10,
#    'min_child_samples': 270,
#    'num_leaves': 34,
#    'reg_alpha': 0.9530967868833456,
#    'reg_lambda': 0.9677983711794952,
#    'subsample': 0.7266578731171478,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 8,
#   'train_time': 66.65505319999647,
#   'status': 'ok'},
#  {'loss': 0.22767875088839962,
#   'auc': 0.7723212491116004,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.8558286895500136,
#    'is_unbalance': False,
#    'learning_rate': 0.06751956730869439,
#    'max_depth': 16,
#    'min_child_samples': 420,
#    'num_leaves': 107,
#    'reg_alpha': 0.16742881296699952,
#    'reg_lambda': 0.1835247337040683,
#    'subsample': 0.6808306595370186,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 9,
#   'train_time': 79.35019169999578,
#   'status': 'ok'},
#  {'loss': 0.23093684039447537,
#   'auc': 0.7690631596055246,
#   'params': {'boosting_type': 'dart',
#    'colsample_bytree': 0.7701421573283638,
#    'is_unbalance': True,
#    'learning_rate': 0.0905653547962815,
#    'max_depth': 16,
#    'min_child_samples': 495,
#    'num_leaves': 123,
#    'reg_alpha': 0.984744648565606,
#    'reg_lambda': 0.25630999714091685,
#    'subsample': 0.9892956303481476,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 10,
#   'train_time': 100.01705080000102,
#   'status': 'ok'},
#  {'loss': 0.2338648669760358,
#   'auc': 0.7661351330239642,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.8342154931081748,
#    'is_unbalance': False,
#    'learning_rate': 0.028848394234718012,
#    'max_depth': 10,
#    'min_child_samples': 485,
#    'num_leaves': 84,
#    'reg_alpha': 0.46888674301373623,
#    'reg_lambda': 0.9202645845010924,
#    'subsample': 0.9379227025218457,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 11,
#   'train_time': 79.13482049999584,
#   'status': 'ok'},
#  {'loss': 0.22885446379874563,
#   'auc': 0.7711455362012544,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.8064852396130944,
#    'is_unbalance': True,
#    'learning_rate': 0.10646092119541842,
#    'max_depth': 10,
#    'min_child_samples': 300,
#    'num_leaves': 57,
#    'reg_alpha': 0.996810630674586,
#    'reg_lambda': 0.24163565106656826,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 12,
#   'train_time': 54.50918819999788,
#   'status': 'ok'},
#  {'loss': 0.23138596905029063,
#   'auc': 0.7686140309497094,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.7213598044145403,
#    'is_unbalance': True,
#    'learning_rate': 0.05192236527448198,
#    'max_depth': 8,
#    'min_child_samples': 205,
#    'num_leaves': 32,
#    'reg_alpha': 0.12249961010067811,
#    'reg_lambda': 0.3151276164659612,
#    'subsample': 0.8617211315941165,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 13,
#   'train_time': 55.23799150000559,
#   'status': 'ok'},
#  {'loss': 0.23329522075426434,
#   'auc': 0.7667047792457357,
#   'params': {'boosting_type': 'dart',
#    'colsample_bytree': 0.7244027053324037,
#    'is_unbalance': True,
#    'learning_rate': 0.12864985364961357,
#    'max_depth': 12,
#    'min_child_samples': 195,
#    'num_leaves': 24,
#    'reg_alpha': 0.9379261293277442,
#    'reg_lambda': 0.6427734957702745,
#    'subsample': 0.6145527294672751,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 14,
#   'train_time': 61.14933430000383,
#   'status': 'ok'},
#  {'loss': 0.2583877872998597,
#   'auc': 0.7416122127001403,
#   'params': {'boosting_type': 'dart',
#    'colsample_bytree': 0.8306467075481436,
#    'is_unbalance': True,
#    'learning_rate': 0.020850436752541765,
#    'max_depth': 14,
#    'min_child_samples': 55,
#    'num_leaves': 25,
#    'reg_alpha': 0.6917962355601563,
#    'reg_lambda': 0.7274111371694961,
#    'subsample': 0.7237690003408792,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 15,
#   'train_time': 64.57091039999796,
#   'status': 'ok'},
#  {'loss': 0.2422161816319035,
#   'auc': 0.7577838183680965,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.777549158211801,
#    'is_unbalance': False,
#    'learning_rate': 0.01422443618324198,
#    'max_depth': 12,
#    'min_child_samples': 375,
#    'num_leaves': 88,
#    'reg_alpha': 0.6405267009297386,
#    'reg_lambda': 0.08664527112460352,
#    'subsample': 0.6929132573210024,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 16,
#   'train_time': 80.37226940000255,
#   'status': 'ok'},
#  {'loss': 0.23694553936214446,
#   'auc': 0.7630544606378555,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.9392389710223309,
#    'is_unbalance': False,
#    'learning_rate': 0.034605019687235575,
#    'max_depth': 12,
#    'min_child_samples': 260,
#    'num_leaves': 29,
#    'reg_alpha': 0.42884672257739975,
#    'reg_lambda': 0.42816622699663665,
#    'subsample': 0.9453506676213383,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 17,
#   'train_time': 59.26598549999471,
#   'status': 'ok'},
#  {'loss': 0.24455862567649744,
#   'auc': 0.7554413743235026,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.8962074338481327,
#    'is_unbalance': False,
#    'learning_rate': 0.011797690545191893,
#    'max_depth': 12,
#    'min_child_samples': 180,
#    'num_leaves': 143,
#    'reg_alpha': 0.6199751150097689,
#    'reg_lambda': 0.6003013797954593,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 18,
#   'train_time': 95.07665200000338,
#   'status': 'ok'},
#  {'loss': 0.2559562281844606,
#   'auc': 0.7440437718155394,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.6578486581551632,
#    'is_unbalance': False,
#    'learning_rate': 0.01648588573262348,
#    'max_depth': 4,
#    'min_child_samples': 470,
#    'num_leaves': 65,
#    'reg_alpha': 0.27214780248352544,
#    'reg_lambda': 0.740027793412593,
#    'subsample': 0.8331822927444228,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 19,
#   'train_time': 42.8451836000022,
#   'status': 'ok'},
#  {'loss': 0.23916999897393598,
#   'auc': 0.760830001026064,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.7863814221949229,
#    'is_unbalance': True,
#    'learning_rate': 0.01721138867599748,
#    'max_depth': 8,
#    'min_child_samples': 355,
#    'num_leaves': 147,
#    'reg_alpha': 0.8170971263106218,
#    'reg_lambda': 0.009431694857899298,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 20,
#   'train_time': 69.5675545999984,
#   'status': 'ok'},
#  {'loss': 0.2437203110995363,
#   'auc': 0.7562796889004637,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.8825875170255091,
#    'is_unbalance': False,
#    'learning_rate': 0.21443808200076753,
#    'max_depth': 18,
#    'min_child_samples': 320,
#    'num_leaves': 55,
#    'reg_alpha': 0.36663285872236406,
#    'reg_lambda': 0.4762795672516824,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 21,
#   'train_time': 52.832485999999335,
#   'status': 'ok'},
#  {'loss': 0.22886115614066382,
#   'auc': 0.7711388438593362,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.9881479874640874,
#    'is_unbalance': False,
#    'learning_rate': 0.0736837481439061,
#    'max_depth': 6,
#    'min_child_samples': 415,
#    'num_leaves': 125,
#    'reg_alpha': 0.34428723372345826,
#    'reg_lambda': 0.18206222282947904,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 22,
#   'train_time': 49.05605139999534,
#   'status': 'ok'},
#  {'loss': 0.2503303551982683,
#   'auc': 0.7496696448017317,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.7374797274859973,
#    'is_unbalance': False,
#    'learning_rate': 0.20293335684305452,
#    'max_depth': 18,
#    'min_child_samples': 305,
#    'num_leaves': 109,
#    'reg_alpha': 0.5381096663785978,
#    'reg_lambda': 0.40633830262147896,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 23,
#   'train_time': 59.823707700008526,
#   'status': 'ok'},
#  {'loss': 0.22853853422286774,
#   'auc': 0.7714614657771323,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.8487021754688033,
#    'is_unbalance': False,
#    'learning_rate': 0.06634867087231353,
#    'max_depth': 16,
#    'min_child_samples': 135,
#    'num_leaves': 72,
#    'reg_alpha': 0.1378418746509376,
#    'reg_lambda': 0.19380295334376396,
#    'subsample': 0.7404846583712061,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 24,
#   'train_time': 67.54487100000551,
#   'status': 'ok'},
#  {'loss': 0.22876930354086844,
#   'auc': 0.7712306964591316,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.9621828893723243,
#    'is_unbalance': False,
#    'learning_rate': 0.06730790684979011,
#    'max_depth': 16,
#    'min_child_samples': 125,
#    'num_leaves': 74,
#    'reg_alpha': 0.14682683811199906,
#    'reg_lambda': 0.0009963582496720635,
#    'subsample': 0.743398548729804,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 25,
#   'train_time': 75.90685070000472,
#   'status': 'ok'},
#  {'loss': 0.23091142881852045,
#   'auc': 0.7690885711814796,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.8635513594080513,
#    'is_unbalance': False,
#    'learning_rate': 0.03763700461868629,
#    'max_depth': 16,
#    'min_child_samples': 125,
#    'num_leaves': 135,
#    'reg_alpha': 0.14698871110489842,
#    'reg_lambda': 0.17368035735198634,
#    'subsample': 0.7547696781742086,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 26,
#   'train_time': 88.30662360000133,
#   'status': 'ok'},
#  {'loss': 0.23321534933215382,
#   'auc': 0.7667846506678462,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.9012267022838715,
#    'is_unbalance': False,
#    'learning_rate': 0.044833250345637066,
#    'max_depth': 18,
#    'min_child_samples': 25,
#    'num_leaves': 43,
#    'reg_alpha': 0.017870294547540994,
#    'reg_lambda': 0.51516931900548,
#    'subsample': 0.601616647343498,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 27,
#   'train_time': 62.900767500002985,
#   'status': 'ok'},
#  {'loss': 0.2291076560851012,
#   'auc': 0.7708923439148988,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.98430535819038,
#    'is_unbalance': False,
#    'learning_rate': 0.06949223489178229,
#    'max_depth': 16,
#    'min_child_samples': 150,
#    'num_leaves': 107,
#    'reg_alpha': 0.3308280762887472,
#    'reg_lambda': 0.15056036858165392,
#    'subsample': 0.732293249527493,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 28,
#   'train_time': 81.79188089999661,
#   'status': 'ok'},
#  {'loss': 0.24604278817912184,
#   'auc': 0.7539572118208782,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.7537425838640872,
#    'is_unbalance': False,
#    'learning_rate': 0.18373673741805557,
#    'max_depth': 14,
#    'min_child_samples': 230,
#    'num_leaves': 115,
#    'reg_alpha': 0.0019052344231170193,
#    'reg_lambda': 0.2400907427757506,
#    'subsample': 0.7990232222068188,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 29,
#   'train_time': 77.32320379999874,
#   'status': 'ok'},
#  {'loss': 0.26693411100769937,
#   'auc': 0.7330658889923006,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.8543950514396454,
#    'is_unbalance': False,
#    'learning_rate': 0.279670042098621,
#    'max_depth': 16,
#    'min_child_samples': 70,
#    'num_leaves': 97,
#    'reg_alpha': 0.09816534655442426,
#    'reg_lambda': 0.5437058623364733,
#    'subsample': 0.68917519968677,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 30,
#   'train_time': 64.28373250000004,
#   'status': 'ok'},
#  {'loss': 0.22792686036069632,
#   'auc': 0.7720731396393037,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.9116757700014597,
#    'is_unbalance': False,
#    'learning_rate': 0.06064483583859573,
#    'max_depth': 18,
#    'min_child_samples': 450,
#    'num_leaves': 76,
#    'reg_alpha': 0.21515229637790972,
#    'reg_lambda': 0.041537461189908004,
#    'subsample': 0.6085820182581138,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 31,
#   'train_time': 79.35522430000128,
#   'status': 'ok'},
#  {'loss': 0.22927531434202886,
#   'auc': 0.7707246856579711,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.914109382166921,
#    'is_unbalance': False,
#    'learning_rate': 0.04493778593786102,
#    'max_depth': 14,
#    'min_child_samples': 450,
#    'num_leaves': 131,
#    'reg_alpha': 0.2479801100324707,
#    'reg_lambda': 0.03295853871577932,
#    'subsample': 0.6019085738209924,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 32,
#   'train_time': 98.69986740000604,
#   'status': 'ok'},
#  {'loss': 0.2388365830867697,
#   'auc': 0.7611634169132303,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.9661639564618636,
#    'is_unbalance': False,
#    'learning_rate': 0.022137619638937872,
#    'max_depth': 18,
#    'min_child_samples': 440,
#    'num_leaves': 83,
#    'reg_alpha': 0.19766446554838096,
#    'reg_lambda': 0.8234538827494593,
#    'subsample': 0.6463476493794708,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 33,
#   'train_time': 86.8606482000032,
#   'status': 'ok'},
#  {'loss': 0.22823995074472836,
#   'auc': 0.7717600492552716,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.8175115088401721,
#    'is_unbalance': False,
#    'learning_rate': 0.08707686541365628,
#    'max_depth': 18,
#    'min_child_samples': 375,
#    'num_leaves': 92,
#    'reg_alpha': 0.418560128906351,
#    'reg_lambda': 0.07470396442705442,
#    'subsample': 0.6060950963853341,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 34,
#   'train_time': 76.21832490000816,
#   'status': 'ok'},
#  {'loss': 0.23103541914554127,
#   'auc': 0.7689645808544587,
#   'params': {'boosting_type': 'dart',
#    'colsample_bytree': 0.6925184917304459,
#    'is_unbalance': False,
#    'learning_rate': 0.16137844660221223,
#    'max_depth': 18,
#    'min_child_samples': 450,
#    'num_leaves': 101,
#    'reg_alpha': 0.5148917957191856,
#    'reg_lambda': 0.107017118413051,
#    'subsample': 0.9892282044036199,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 35,
#   'train_time': 87.29483400000026,
#   'status': 'ok'},
#  {'loss': 0.23171069827282997,
#   'auc': 0.76828930172717,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.925690356476166,
#    'is_unbalance': False,
#    'learning_rate': 0.054789343846960645,
#    'max_depth': 6,
#    'min_child_samples': 390,
#    'num_leaves': 116,
#    'reg_alpha': 0.19183066255545497,
#    'reg_lambda': 0.37426570514542423,
#    'subsample': 0.6762597672297253,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 36,
#   'train_time': 59.92514510000183,
#   'status': 'ok'},
#  {'loss': 0.2357743794045628,
#   'auc': 0.7642256205954372,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.9571319003501128,
#    'is_unbalance': False,
#    'learning_rate': 0.031614635967919774,
#    'max_depth': 14,
#    'min_child_samples': 500,
#    'num_leaves': 44,
#    'reg_alpha': 0.05196222475072024,
#    'reg_lambda': 0.2863292129459637,
#    'subsample': 0.7942317477703669,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 37,
#   'train_time': 72.43941969999287,
#   'status': 'ok'},
#  {'loss': 0.2418951433476435,
#   'auc': 0.7581048566523565,
#   'params': {'boosting_type': 'dart',
#    'colsample_bytree': 0.9031241649586873,
#    'is_unbalance': False,
#    'learning_rate': 0.040812397313967456,
#    'max_depth': 16,
#    'min_child_samples': 335,
#    'num_leaves': 80,
#    'reg_alpha': 0.3051897096994456,
#    'reg_lambda': 0.13236798912599346,
#    'subsample': 0.9124391251272843,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 38,
#   'train_time': 89.6033097999898,
#   'status': 'ok'},
#  {'loss': 0.23121141595248473,
#   'auc': 0.7687885840475153,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.9456977724399539,
#    'is_unbalance': False,
#    'learning_rate': 0.11907862476244153,
#    'max_depth': 18,
#    'min_child_samples': 420,
#    'num_leaves': 75,
#    'reg_alpha': 0.38901177778151574,
#    'reg_lambda': 0.03967953806355415,
#    'subsample': 0.8918599175708979,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 39,
#   'train_time': 75.90196679999644,
#   'status': 'ok'},
#  {'loss': 0.22848396450948738,
#   'auc': 0.7715160354905126,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.8792063331262653,
#    'is_unbalance': False,
#    'learning_rate': 0.0564787897074877,
#    'max_depth': 14,
#    'min_child_samples': 475,
#    'num_leaves': 61,
#    'reg_alpha': 0.5575128246689784,
#    'reg_lambda': 0.3467108980707543,
#    'subsample': 0.704726636250036,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 40,
#   'train_time': 74.15699470000982,
#   'status': 'ok'},
#  {'loss': 0.23290204808176052,
#   'auc': 0.7670979519182395,
#   'params': {'boosting_type': 'dart',
#    'colsample_bytree': 0.600743927190216,
#    'is_unbalance': True,
#    'learning_rate': 0.29777211154934563,
#    'max_depth': 16,
#    'min_child_samples': 290,
#    'num_leaves': 50,
#    'reg_alpha': 0.46417800604479664,
#    'reg_lambda': 0.46356368096051515,
#    'subsample': 0.6044553542660526,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 41,
#   'train_time': 67.03265710000414,
#   'status': 'ok'},
#  {'loss': 0.2299354726857894,
#   'auc': 0.7700645273142106,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.9991426091288333,
#    'is_unbalance': False,
#    'learning_rate': 0.08620696766173194,
#    'max_depth': 6,
#    'min_child_samples': 400,
#    'num_leaves': 91,
#    'reg_alpha': 0.08117689312202697,
#    'reg_lambda': 0.2307810671859697,
#    'subsample': 0.6247836535269362,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 42,
#   'train_time': 56.287409900003695,
#   'status': 'ok'},
#  {'loss': 0.2351607122301319,
#   'auc': 0.7648392877698681,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.8145448063880607,
#    'is_unbalance': True,
#    'learning_rate': 0.024923664564745443,
#    'max_depth': 10,
#    'min_child_samples': 435,
#    'num_leaves': 98,
#    'reg_alpha': 0.2239054967507702,
#    'reg_lambda': 0.2953493781011639,
#    'subsample': 0.6670612230803852,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 43,
#   'train_time': 81.17129940001178,
#   'status': 'ok'},
#  {'loss': 0.2528551938041974,
#   'auc': 0.7471448061958026,
#   'params': {'boosting_type': 'dart',
#    'colsample_bytree': 0.8772008393105589,
#    'is_unbalance': False,
#    'learning_rate': 0.01024179802909028,
#    'max_depth': 14,
#    'min_child_samples': 350,
#    'num_leaves': 110,
#    'reg_alpha': 0.3002960760181523,
#    'reg_lambda': 0.05807747031360411,
#    'subsample': 0.8795787666043674,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 44,
#   'train_time': 101.94052520001424,
#   'status': 'ok'},
#  {'loss': 0.23096919220475842,
#   'auc': 0.7690308077952416,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.8348023168022477,
#    'is_unbalance': True,
#    'learning_rate': 0.10276322946986768,
#    'max_depth': 18,
#    'min_child_samples': 465,
#    'num_leaves': 130,
#    'reg_alpha': 0.03914176103584499,
#    'reg_lambda': 0.0038044605331480907,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 45,
#   'train_time': 74.17494409999927,
#   'status': 'ok'},
#  {'loss': 0.2292549707795153,
#   'auc': 0.7707450292204847,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.7595661602735817,
#    'is_unbalance': False,
#    'learning_rate': 0.04954013377780443,
#    'max_depth': 12,
#    'min_child_samples': 235,
#    'num_leaves': 139,
#    'reg_alpha': 0.19365682426089637,
#    'reg_lambda': 0.5849707912412081,
#    'subsample': 0.7756505305825403,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 46,
#   'train_time': 97.7586103999929,
#   'status': 'ok'},
#  {'loss': 0.23676106528714536,
#   'auc': 0.7632389347128546,
#   'params': {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.9221760614188657,
#    'is_unbalance': False,
#    'learning_rate': 0.1370224660933397,
#    'max_depth': 10,
#    'min_child_samples': 375,
#    'num_leaves': 119,
#    'reg_alpha': 0.78597777299024,
#    'reg_lambda': 0.12788948016658586,
#    'subsample': 0.7166793280242191,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 47,
#   'train_time': 83.14695579999534,
#   'status': 'ok'},
#  {'loss': 0.23245340754279697,
#   'auc': 0.767546592457203,
#   'params': {'boosting_type': 'dart',
#    'colsample_bytree': 0.6321262599245726,
#    'is_unbalance': True,
#    'learning_rate': 0.07957241633313789,
#    'max_depth': 8,
#    'min_child_samples': 495,
#    'num_leaves': 69,
#    'reg_alpha': 0.7096111132874419,
#    'reg_lambda': 0.20582416920955018,
#    'subsample': 0.9247961289789338,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 48,
#   'train_time': 75.38049579999642,
#   'status': 'ok'},
#  {'loss': 0.22665111993063025,
#   'auc': 0.7733488800693697,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.8033845649164827,
#    'is_unbalance': False,
#    'learning_rate': 0.058964080355423776,
#    'max_depth': 12,
#    'min_child_samples': 340,
#    'num_leaves': 80,
#    'reg_alpha': 0.4748405479945878,
#    'reg_lambda': 0.8629344536104161,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 49,
#   'train_time': 62.620908900004,
#   'status': 'ok'},
#  {'loss': 0.23191386370703382,
#   'auc': 0.7680861362929662,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.7106109095043001,
#    'is_unbalance': False,
#    'learning_rate': 0.02847039711008135,
#    'max_depth': 12,
#    'min_child_samples': 290,
#    'num_leaves': 103,
#    'reg_alpha': 0.5795143910189032,
#    'reg_lambda': 0.9971710048665818,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 50,
#   'train_time': 72.95473640000273,
#   'status': 'ok'},
#  {'loss': 0.23566734422580526,
#   'auc': 0.7643326557741947,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.7993240784268744,
#    'is_unbalance': True,
#    'learning_rate': 0.15882833520173598,
#    'max_depth': 10,
#    'min_child_samples': 320,
#    'num_leaves': 63,
#    'reg_alpha': 0.6518531169544385,
#    'reg_lambda': 0.8407946246122849,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 51,
#   'train_time': 59.420486399991205,
#   'status': 'ok'},
#  {'loss': 0.24921048495268916,
#   'auc': 0.7507895150473108,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6744567884706141,
#    'is_unbalance': False,
#    'learning_rate': 0.25283554022872956,
#    'max_depth': 8,
#    'min_child_samples': 220,
#    'num_leaves': 89,
#    'reg_alpha': 0.8928046599027006,
#    'reg_lambda': 0.9044798203683236,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 52,
#   'train_time': 52.409190100006526,
#   'status': 'ok'},
#  {'loss': 0.23035033014178774,
#   'auc': 0.7696496698582123,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.7410464447555285,
#    'is_unbalance': False,
#    'learning_rate': 0.033027423466134416,
#    'max_depth': 12,
#    'min_child_samples': 175,
#    'num_leaves': 148,
#    'reg_alpha': 0.48375525946671843,
#    'reg_lambda': 0.6745729711823566,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 53,
#   'train_time': 81.49638240000058,
#   'status': 'ok'},
#  {'loss': 0.23079907460297133,
#   'auc': 0.7692009253970287,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.7827354536384565,
#    'is_unbalance': True,
#    'learning_rate': 0.10831115482169938,
#    'max_depth': 4,
#    'min_child_samples': 275,
#    'num_leaves': 38,
#    'reg_alpha': 0.8608669100610977,
#    'reg_lambda': 0.79707852502577,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 54,
#   'train_time': 44.577199699997436,
#   'status': 'ok'},
#  {'loss': 0.2340558311593396,
#   'auc': 0.7659441688406604,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6232180193069915,
#    'is_unbalance': False,
#    'learning_rate': 0.01932744484270342,
#    'max_depth': 14,
#    'min_child_samples': 245,
#    'num_leaves': 124,
#    'reg_alpha': 0.42259655987525996,
#    'reg_lambda': 0.7720320009896573,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 55,
#   'train_time': 77.52692470001057,
#   'status': 'ok'},
#  {'loss': 0.22875247099638774,
#   'auc': 0.7712475290036123,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.847805602426955,
#    'is_unbalance': False,
#    'learning_rate': 0.09595869444481485,
#    'max_depth': 8,
#    'min_child_samples': 360,
#    'num_leaves': 80,
#    'reg_alpha': 0.6808911317481282,
#    'reg_lambda': 0.8846246187523138,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 56,
#   'train_time': 56.693067000000156,
#   'status': 'ok'},
#  {'loss': 0.2316710844737243,
#   'auc': 0.7683289155262757,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.7674252422274914,
#    'is_unbalance': False,
#    'learning_rate': 0.038556815468576866,
#    'max_depth': 12,
#    'min_child_samples': 320,
#    'num_leaves': 52,
#    'reg_alpha': 0.3914348130827029,
#    'reg_lambda': 0.969277057137573,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 57,
#   'train_time': 60.368571700004395,
#   'status': 'ok'},
#  {'loss': 0.2344775944456532,
#   'auc': 0.7655224055543468,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.821585454274731,
#    'is_unbalance': True,
#    'learning_rate': 0.02425275528871475,
#    'max_depth': 10,
#    'min_child_samples': 425,
#    'num_leaves': 112,
#    'reg_alpha': 0.7716576674926198,
#    'reg_lambda': 0.6540855069800408,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 58,
#   'train_time': 75.93173279998882,
#   'status': 'ok'},
#  {'loss': 0.22882273286092047,
#   'auc': 0.7711772671390795,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.7938059538768301,
#    'is_unbalance': False,
#    'learning_rate': 0.047656973714872326,
#    'max_depth': 14,
#    'min_child_samples': 335,
#    'num_leaves': 59,
#    'reg_alpha': 0.5947374077761091,
#    'reg_lambda': 0.6056157072031214,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 59,
#   'train_time': 62.14514350000536,
#   'status': 'ok'},
#  {'loss': 0.24004575328834576,
#   'auc': 0.7599542467116542,
#   'params': {'boosting_type': 'dart',
#    'colsample_bytree': 0.6973384171903928,
#    'is_unbalance': False,
#    'learning_rate': 0.07773368041782114,
#    'max_depth': 6,
#    'min_child_samples': 390,
#    'num_leaves': 21,
#    'reg_alpha': 0.5265902825774949,
#    'reg_lambda': 0.5626366931200364,
#    'subsample': 0.6780038848218162,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 60,
#   'train_time': 58.48594279999088,
#   'status': 'ok'},
#  {'loss': 0.2272799340417564,
#   'auc': 0.7727200659582436,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.889014207155672,
#    'is_unbalance': False,
#    'learning_rate': 0.05957718458507161,
#    'max_depth': 16,
#    'min_child_samples': 405,
#    'num_leaves': 68,
#    'reg_alpha': 0.27973001708032275,
#    'reg_lambda': 0.7124800343185708,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 61,
#   'train_time': 66.19856539998727,
#   'status': 'ok'},
#  {'loss': 0.22806157951326633,
#   'auc': 0.7719384204867337,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.8408933880227093,
#    'is_unbalance': False,
#    'learning_rate': 0.06132945246459729,
#    'max_depth': 16,
#    'min_child_samples': 275,
#    'num_leaves': 68,
#    'reg_alpha': 0.4510904692920043,
#    'reg_lambda': 0.7372996410774748,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 62,
#   'train_time': 63.89333359999,
#   'status': 'ok'},
#  {'loss': 0.24425985268732664,
#   'auc': 0.7557401473126734,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.7327549556854174,
#    'is_unbalance': True,
#    'learning_rate': 0.015320317098325684,
#    'max_depth': 10,
#    'min_child_samples': 400,
#    'num_leaves': 47,
#    'reg_alpha': 0.2707880315893558,
#    'reg_lambda': 0.7040751611359266,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 63,
#   'train_time': 67.85359569999855,
#   'status': 'ok'},
#  {'loss': 0.22909996614001094,
#   'auc': 0.7709000338599891,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.8654309601444374,
#    'is_unbalance': False,
#    'learning_rate': 0.12442069148198563,
#    'max_depth': 12,
#    'min_child_samples': 195,
#    'num_leaves': 36,
#    'reg_alpha': 0.4964956271985732,
#    'reg_lambda': 0.9471819625472799,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 64,
#   'train_time': 54.34618710000359,
#   'status': 'ok'},
#  {'loss': 0.2348280715834139,
#   'auc': 0.7651719284165861,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.7532127266816451,
#    'is_unbalance': False,
#    'learning_rate': 0.14779563353809427,
#    'max_depth': 14,
#    'min_child_samples': 335,
#    'num_leaves': 79,
#    'reg_alpha': 0.36573378908766185,
#    'reg_lambda': 0.8603988407017553,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 65,
#   'train_time': 63.24777929999982,
#   'status': 'ok'},
#  {'loss': 0.228826460561099,
#   'auc': 0.771173539438901,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.8894211922087043,
#    'is_unbalance': False,
#    'learning_rate': 0.042472506120754816,
#    'max_depth': 16,
#    'min_child_samples': 365,
#    'num_leaves': 70,
#    'reg_alpha': 0.1677907470079066,
#    'reg_lambda': 0.6281288921766159,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 66,
#   'train_time': 70.37095569999656,
#   'status': 'ok'},
#  {'loss': 0.22669736369433813,
#   'auc': 0.7733026363056619,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.8056448317387331,
#    'is_unbalance': False,
#    'learning_rate': 0.05811560208323983,
#    'max_depth': 16,
#    'min_child_samples': 390,
#    'num_leaves': 106,
#    'reg_alpha': 0.32873145785274543,
#    'reg_lambda': 0.5163335294043806,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 67,
#   'train_time': 73.60853500000667,
#   'status': 'ok'},
#  {'loss': 0.22752188356447955,
#   'auc': 0.7724781164355204,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.8017734241956836,
#    'is_unbalance': False,
#    'learning_rate': 0.06101870673963551,
#    'max_depth': 14,
#    'min_child_samples': 305,
#    'num_leaves': 95,
#    'reg_alpha': 0.3334692614814386,
#    'reg_lambda': 0.5259751802808863,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 68,
#   'train_time': 67.09690709999995,
#   'status': 'ok'},
#  {'loss': 0.2302789933420022,
#   'auc': 0.7697210066579978,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.7754138068663932,
#    'is_unbalance': False,
#    'learning_rate': 0.03527056114632788,
#    'max_depth': 16,
#    'min_child_samples': 385,
#    'num_leaves': 84,
#    'reg_alpha': 0.2989452383335174,
#    'reg_lambda': 0.7930287138628282,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 69,
#   'train_time': 65.82644829999481,
#   'status': 'ok'},
#  {'loss': 0.2311317534938292,
#   'auc': 0.7688682465061708,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.8138903520300561,
#    'is_unbalance': False,
#    'learning_rate': 0.0308964663122837,
#    'max_depth': 16,
#    'min_child_samples': 415,
#    'num_leaves': 100,
#    'reg_alpha': 0.24213337796519543,
#    'reg_lambda': 0.4558522705979874,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 70,
#   'train_time': 72.47261790001357,
#   'status': 'ok'},
#  {'loss': 0.22729284795709392,
#   'auc': 0.7727071520429061,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.8274341378431243,
#    'is_unbalance': False,
#    'learning_rate': 0.051851456103980516,
#    'max_depth': 18,
#    'min_child_samples': 480,
#    'num_leaves': 106,
#    'reg_alpha': 0.5564452781175768,
#    'reg_lambda': 0.7648916590660462,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 71,
#   'train_time': 71.59809480000695,
#   'status': 'ok'},
#  {'loss': 0.22748801365434768,
#   'auc': 0.7725119863456523,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.859795267561644,
#    'is_unbalance': False,
#    'learning_rate': 0.08196146401822094,
#    'max_depth': 14,
#    'min_child_samples': 465,
#    'num_leaves': 87,
#    'reg_alpha': 0.40178928861722013,
#    'reg_lambda': 0.7004902154272244,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 72,
#   'train_time': 66.80980639999325,
#   'status': 'ok'},
#  {'loss': 0.22895256113429552,
#   'auc': 0.7710474388657045,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.7124782465951361,
#    'is_unbalance': False,
#    'learning_rate': 0.11192923199756522,
#    'max_depth': 12,
#    'min_child_samples': 435,
#    'num_leaves': 65,
#    'reg_alpha': 0.10766608134415204,
#    'reg_lambda': 0.4855188822174333,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 73,
#   'train_time': 56.88101779999852,
#   'status': 'ok'},
#  {'loss': 0.22908243456305688,
#   'auc': 0.7709175654369431,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.9746899542280942,
#    'is_unbalance': False,
#    'learning_rate': 0.09245813401293138,
#    'max_depth': 18,
#    'min_child_samples': 250,
#    'num_leaves': 56,
#    'reg_alpha': 0.44513058361261726,
#    'reg_lambda': 0.42705253633000084,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 74,
#   'train_time': 59.75687209999887,
#   'status': 'ok'},
#  {'loss': 0.2281587850328386,
#   'auc': 0.7718412149671614,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.9435814512204197,
#    'is_unbalance': False,
#    'learning_rate': 0.07237450604532371,
#    'max_depth': 16,
#    'min_child_samples': 320,
#    'num_leaves': 93,
#    'reg_alpha': 0.27694942086850327,
#    'reg_lambda': 0.37799535970289144,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 75,
#   'train_time': 68.82377049999195,
#   'status': 'ok'},
#  {'loss': 0.2339983145575356,
#   'auc': 0.7660016854424644,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.7904217408215365,
#    'is_unbalance': False,
#    'learning_rate': 0.026805513168385288,
#    'max_depth': 18,
#    'min_child_samples': 405,
#    'num_leaves': 73,
#    'reg_alpha': 0.3586177324709344,
#    'reg_lambda': 0.6706117128310618,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 76,
#   'train_time': 68.70333940000273,
#   'status': 'ok'},
#  {'loss': 0.2293079990532385,
#   'auc': 0.7706920009467615,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.8919755145601619,
#    'is_unbalance': False,
#    'learning_rate': 0.06461983403583958,
#    'max_depth': 16,
#    'min_child_samples': 340,
#    'num_leaves': 28,
#    'reg_alpha': 0.3162632724183466,
#    'reg_lambda': 0.5616055192711693,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 77,
#   'train_time': 52.648849200006225,
#   'status': 'ok'},
#  {'loss': 0.23510856494686294,
#   'auc': 0.7648914350531371,
#   'params': {'boosting_type': 'dart',
#    'colsample_bytree': 0.8693292006152697,
#    'is_unbalance': False,
#    'learning_rate': 0.057361629880707025,
#    'max_depth': 14,
#    'min_child_samples': 370,
#    'num_leaves': 119,
#    'reg_alpha': 0.6167258363401817,
#    'reg_lambda': 0.8221043958387217,
#    'subsample': 0.7618928279549982,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 78,
#   'train_time': 111.27081719999842,
#   'status': 'ok'},
#  {'loss': 0.22909127837650722,
#   'auc': 0.7709087216234928,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.9120709183806022,
#    'is_unbalance': False,
#    'learning_rate': 0.04748530331401579,
#    'max_depth': 12,
#    'min_child_samples': 295,
#    'num_leaves': 79,
#    'reg_alpha': 0.1581603438045882,
#    'reg_lambda': 0.9870859179172428,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 79,
#   'train_time': 68.64563360001193,
#   'status': 'ok'},
#  {'loss': 0.22905331369903104,
#   'auc': 0.770946686300969,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.8093508468701561,
#    'is_unbalance': True,
#    'learning_rate': 0.035649477026932476,
#    'max_depth': 16,
#    'min_child_samples': 350,
#    'num_leaves': 128,
#    'reg_alpha': 0.48207100815001547,
#    'reg_lambda': 0.6241309564286164,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 80,
#   'train_time': 76.67395630000101,
#   'status': 'ok'},
#  {'loss': 0.22824894439190158,
#   'auc': 0.7717510556080984,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.7658377561824701,
#    'is_unbalance': False,
#    'learning_rate': 0.09956092211148741,
#    'max_depth': 18,
#    'min_child_samples': 455,
#    'num_leaves': 86,
#    'reg_alpha': 0.26865987084664694,
#    'reg_lambda': 0.9181889355514152,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 81,
#   'train_time': 67.4557313999976,
#   'status': 'ok'},
#  {'loss': 0.23804300759437202,
#   'auc': 0.761956992405628,
#   'params': {'boosting_type': 'dart',
#    'colsample_bytree': 0.7446110533080154,
#    'is_unbalance': False,
#    'learning_rate': 0.22921475841271607,
#    'max_depth': 14,
#    'min_child_samples': 260,
#    'num_leaves': 136,
#    'reg_alpha': 0.2239398341291864,
#    'reg_lambda': 0.5064950968145239,
#    'subsample': 0.64580364158852,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 82,
#   'train_time': 102.96067520001088,
#   'status': 'ok'},
#  {'loss': 0.22852015283326077,
#   'auc': 0.7714798471667392,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.8439979556787647,
#    'is_unbalance': False,
#    'learning_rate': 0.03992335096700904,
#    'max_depth': 12,
#    'min_child_samples': 425,
#    'num_leaves': 103,
#    'reg_alpha': 0.7347927647913083,
#    'reg_lambda': 0.7211207625326326,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 83,
#   'train_time': 73.20456909999484,
#   'status': 'ok'},
#  {'loss': 0.23372467476566572,
#   'auc': 0.7662753252343343,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.9346033694641056,
#    'is_unbalance': False,
#    'learning_rate': 0.1831183836523856,
#    'max_depth': 8,
#    'min_child_samples': 405,
#    'num_leaves': 60,
#    'reg_alpha': 0.07417540533611011,
#    'reg_lambda': 0.8836839074932269,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 84,
#   'train_time': 55.47657759999856,
#   'status': 'ok'},
#  {'loss': 0.2522877445325966,
#   'auc': 0.7477122554674034,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.9543655844858595,
#    'is_unbalance': True,
#    'learning_rate': 0.01308087279817622,
#    'max_depth': 10,
#    'min_child_samples': 385,
#    'num_leaves': 42,
#    'reg_alpha': 0.6483744292662788,
#    'reg_lambda': 0.3290708631125141,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 85,
#   'train_time': 70.5278621000034,
#   'status': 'ok'},
#  {'loss': 0.26215218902403803,
#   'auc': 0.737847810975962,
#   'params': {'boosting_type': 'dart',
#    'colsample_bytree': 0.678513492067516,
#    'is_unbalance': False,
#    'learning_rate': 0.019190661687217565,
#    'max_depth': 4,
#    'min_child_samples': 490,
#    'num_leaves': 49,
#    'reg_alpha': 0.561345197809531,
#    'reg_lambda': 0.5854832899389597,
#    'subsample': 0.949618868638094,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 86,
#   'train_time': 53.82044940000924,
#   'status': 'ok'},
#  {'loss': 0.22840238017222503,
#   'auc': 0.771597619827775,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.8754277709088876,
#    'is_unbalance': False,
#    'learning_rate': 0.04274199061706074,
#    'max_depth': 14,
#    'min_child_samples': 440,
#    'num_leaves': 113,
#    'reg_alpha': 0.3495537020617248,
#    'reg_lambda': 0.7547925078842199,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 87,
#   'train_time': 79.79061799999909,
#   'status': 'ok'},
#  {'loss': 0.22749321170040526,
#   'auc': 0.7725067882995947,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.8265540305551128,
#    'is_unbalance': False,
#    'learning_rate': 0.053766623428829166,
#    'max_depth': 18,
#    'min_child_samples': 305,
#    'num_leaves': 90,
#    'reg_alpha': 0.5146957993281271,
#    'reg_lambda': 0.8047319122114938,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 88,
#   'train_time': 73.37246169999707,
#   'status': 'ok'},
#  {'loss': 0.2269606881349111,
#   'auc': 0.7730393118650889,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.7252391821268044,
#    'is_unbalance': True,
#    'learning_rate': 0.07239085779601773,
#    'max_depth': 16,
#    'min_child_samples': 285,
#    'num_leaves': 76,
#    'reg_alpha': 0.17573645963167694,
#    'reg_lambda': 0.945378928402389,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 89,
#   'train_time': 60.41409489999933,
#   'status': 'ok'},
#  {'loss': 0.2285508387452111,
#   'auc': 0.7714491612547889,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.7251274121938475,
#    'is_unbalance': True,
#    'learning_rate': 0.07009274648811029,
#    'max_depth': 6,
#    'min_child_samples': 210,
#    'num_leaves': 96,
#    'reg_alpha': 0.02109804891284628,
#    'reg_lambda': 0.9598380934605907,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 90,
#   'train_time': 49.44370030000573,
#   'status': 'ok'},
#  {'loss': 0.23340511757471372,
#   'auc': 0.7665948824252863,
#   'params': {'boosting_type': 'dart',
#    'colsample_bytree': 0.6248169403231444,
#    'is_unbalance': True,
#    'learning_rate': 0.07692568369115703,
#    'max_depth': 18,
#    'min_child_samples': 170,
#    'num_leaves': 77,
#    'reg_alpha': 0.127532058015509,
#    'reg_lambda': 0.853367512672876,
#    'subsample': 0.781500665780767,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 91,
#   'train_time': 74.82951650000177,
#   'status': 'ok'},
#  {'loss': 0.23211466870001274,
#   'auc': 0.7678853312999873,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6580448797737836,
#    'is_unbalance': True,
#    'learning_rate': 0.11839564660864976,
#    'max_depth': 12,
#    'min_child_samples': 235,
#    'num_leaves': 82,
#    'reg_alpha': 0.37966773708029966,
#    'reg_lambda': 0.8912574048780554,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 92,
#   'train_time': 53.81765479999012,
#   'status': 'ok'},
#  {'loss': 0.22822823680787274,
#   'auc': 0.7717717631921273,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6971787159319836,
#    'is_unbalance': True,
#    'learning_rate': 0.08906449171398384,
#    'max_depth': 14,
#    'min_child_samples': 280,
#    'num_leaves': 100,
#    'reg_alpha': 0.10845139257740616,
#    'reg_lambda': 0.976162412610635,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 93,
#   'train_time': 59.37970249999489,
#   'status': 'ok'},
#  {'loss': 0.22949095335771108,
#   'auc': 0.7705090466422889,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6381914048536182,
#    'is_unbalance': True,
#    'learning_rate': 0.04540814075577454,
#    'max_depth': 8,
#    'min_child_samples': 105,
#    'num_leaves': 110,
#    'reg_alpha': 0.4124777869557356,
#    'reg_lambda': 0.9388910690170365,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 94,
#   'train_time': 57.38812809999217,
#   'status': 'ok'},
#  {'loss': 0.23420241472842596,
#   'auc': 0.765797585271574,
#   'params': {'boosting_type': 'dart',
#    'colsample_bytree': 0.7096708151351124,
#    'is_unbalance': True,
#    'learning_rate': 0.17982632223901093,
#    'max_depth': 12,
#    'min_child_samples': 40,
#    'num_leaves': 142,
#    'reg_alpha': 0.44295360738117356,
#    'reg_lambda': 0.9967356538606257,
#    'subsample': 0.867211558765504,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 95,
#   'train_time': 85.3918810000032,
#   'status': 'ok'},
#  {'loss': 0.23817302210595304,
#   'auc': 0.761826977894047,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6477523445981284,
#    'is_unbalance': True,
#    'learning_rate': 0.14643533202221193,
#    'max_depth': 10,
#    'min_child_samples': 190,
#    'num_leaves': 116,
#    'reg_alpha': 0.23727412085535643,
#    'reg_lambda': 0.39968570007495874,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 96,
#   'train_time': 53.95732020000287,
#   'status': 'ok'},
#  {'loss': 0.23450740520251723,
#   'auc': 0.7654925947974828,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.7510259180168498,
#    'is_unbalance': True,
#    'learning_rate': 0.02226957671728252,
#    'max_depth': 16,
#    'min_child_samples': 265,
#    'num_leaves': 106,
#    'reg_alpha': 0.32024715009324706,
#    'reg_lambda': 0.2812867548697454,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 97,
#   'train_time': 71.24666910000087,
#   'status': 'ok'},
#  {'loss': 0.2270849119449011,
#   'auc': 0.7729150880550989,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6810210900477041,
#    'is_unbalance': True,
#    'learning_rate': 0.08311919391279117,
#    'max_depth': 14,
#    'min_child_samples': 330,
#    'num_leaves': 63,
# ...
#    'colsample_bytree': 0.755149971729251,
#    'is_unbalance': True,
#    'learning_rate': 0.0929649637036111,
#    'max_depth': 8,
#    'min_child_samples': 225,
#    'num_leaves': 41,
#    'reg_alpha': 0.21403743339294873,
#    'reg_lambda': 0.5168571139811253,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 249,
#   'train_time': 51.45819960000517,
#   'status': 'ok'},
#  {'loss': 0.23864325098957795,
#   'auc': 0.761356749010422,
#   'params': {'boosting_type': 'dart',
#    'colsample_bytree': 0.6449579309953074,
#    'is_unbalance': False,
#    'learning_rate': 0.04272323067834039,
#    'max_depth': 16,
#    'min_child_samples': 355,
#    'num_leaves': 63,
#    'reg_alpha': 0.3439492828580579,
#    'reg_lambda': 0.29967059925039735,
#    'subsample': 0.9340876822446553,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 250,
#   'train_time': 77.40827859999263,
#   'status': 'ok'},
#  {'loss': 0.23985461360942018,
#   'auc': 0.7601453863905798,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.8467150627972531,
#    'is_unbalance': True,
#    'learning_rate': 0.1620227391935909,
#    'max_depth': 18,
#    'min_child_samples': 390,
#    'num_leaves': 101,
#    'reg_alpha': 0.5428491549229448,
#    'reg_lambda': 0.4137854121144393,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 251,
#   'train_time': 64.68748180000694,
#   'status': 'ok'},
#  {'loss': 0.23213780162660103,
#   'auc': 0.767862198373399,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.9220363859405987,
#    'is_unbalance': False,
#    'learning_rate': 0.030158559260270928,
#    'max_depth': 14,
#    'min_child_samples': 180,
#    'num_leaves': 111,
#    'reg_alpha': 0.4311722662421499,
#    'reg_lambda': 0.7286651422529098,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 253,
#   'train_time': 82.4726265000063,
#   'status': 'ok'},
#  {'loss': 0.22698028988593888,
#   'auc': 0.7730197101140611,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.7953300125380828,
#    'is_unbalance': True,
#    'learning_rate': 0.05912555927241926,
#    'max_depth': 12,
#    'min_child_samples': 450,
#    'num_leaves': 122,
#    'reg_alpha': 0.12119842236981859,
#    'reg_lambda': 0.2017414313435838,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 254,
#   'train_time': 73.4284164000128,
#   'status': 'ok'},
#  {'loss': 0.228102605740221,
#   'auc': 0.771897394259779,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.7247563326558965,
#    'is_unbalance': False,
#    'learning_rate': 0.08407292198062463,
#    'max_depth': 10,
#    'min_child_samples': 375,
#    'num_leaves': 106,
#    'reg_alpha': 0.2707004080762856,
#    'reg_lambda': 0.8591217196708887,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 255,
#   'train_time': 61.36629209999228,
#   'status': 'ok'},
#  {'loss': 0.22971633484339615,
#   'auc': 0.7702836651566038,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.945448868944738,
#    'is_unbalance': True,
#    'learning_rate': 0.07712458628001014,
#    'max_depth': 16,
#    'min_child_samples': 75,
#    'num_leaves': 45,
#    'reg_alpha': 0.5984854012510671,
#    'reg_lambda': 0.3454460104671643,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 256,
#   'train_time': 56.905751500002225,
#   'status': 'ok'},
#  {'loss': 0.2353187097451236,
#   'auc': 0.7646812902548764,
#   'params': {'boosting_type': 'dart',
#    'colsample_bytree': 0.6007932622005393,
#    'is_unbalance': False,
#    'learning_rate': 0.04906982537931922,
#    'max_depth': 14,
#    'min_child_samples': 410,
#    'num_leaves': 82,
#    'reg_alpha': 0.08301688597716775,
#    'reg_lambda': 0.8238148476776683,
#    'subsample': 0.6022168952744947,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 257,
#   'train_time': 81.77634430000035,
#   'status': 'ok'},
#  {'loss': 0.23498883817328764,
#   'auc': 0.7650111618267124,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.880969343583099,
#    'is_unbalance': True,
#    'learning_rate': 0.11212247556707788,
#    'max_depth': 18,
#    'min_child_samples': 345,
#    'num_leaves': 149,
#    'reg_alpha': 0.23702865511612325,
#    'reg_lambda': 0.773313758598082,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 258,
#   'train_time': 72.93749280000338,
#   'status': 'ok'},
#  {'loss': 0.22817495146657962,
#   'auc': 0.7718250485334204,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.7773287189982692,
#    'is_unbalance': False,
#    'learning_rate': 0.053552505185633016,
#    'max_depth': 14,
#    'min_child_samples': 285,
#    'num_leaves': 74,
#    'reg_alpha': 0.29771639172758657,
#    'reg_lambda': 0.5928008032661904,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 259,
#   'train_time': 60.691586899993126,
#   'status': 'ok'},
#  {'loss': 0.22735884050148114,
#   'auc': 0.7726411594985189,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6156751468937969,
#    'is_unbalance': True,
#    'learning_rate': 0.06665445749143248,
#    'max_depth': 12,
#    'min_child_samples': 300,
#    'num_leaves': 119,
#    'reg_alpha': 0.8910388607006332,
#    'reg_lambda': 0.46812757092466817,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 260,
#   'train_time': 61.495027500001015,
#   'status': 'ok'},
#  {'loss': 0.22738807143350603,
#   'auc': 0.772611928566494,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6406002190782858,
#    'is_unbalance': True,
#    'learning_rate': 0.07391078922313633,
#    'max_depth': 12,
#    'min_child_samples': 310,
#    'num_leaves': 131,
#    'reg_alpha': 0.7494911036087226,
#    'reg_lambda': 0.49826946407411515,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 261,
#   'train_time': 61.6720084999979,
#   'status': 'ok'},
#  {'loss': 0.2270553827553108,
#   'auc': 0.7729446172446892,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6336626591001427,
#    'is_unbalance': True,
#    'learning_rate': 0.06532236662813895,
#    'max_depth': 10,
#    'min_child_samples': 300,
#    'num_leaves': 127,
#    'reg_alpha': 0.8708449120176485,
#    'reg_lambda': 0.5048139305273601,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 262,
#   'train_time': 60.33227420000185,
#   'status': 'ok'},
#  {'loss': 0.22762239819460928,
#   'auc': 0.7723776018053907,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6100271134438716,
#    'is_unbalance': True,
#    'learning_rate': 0.045633700111262034,
#    'max_depth': 12,
#    'min_child_samples': 320,
#    'num_leaves': 136,
#    'reg_alpha': 0.9183979230427977,
#    'reg_lambda': 0.572809187014609,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 263,
#   'train_time': 64.69629249999707,
#   'status': 'ok'},
#  {'loss': 0.22736666449968657,
#   'auc': 0.7726333355003134,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6253364312476273,
#    'is_unbalance': True,
#    'learning_rate': 0.06404838047826364,
#    'max_depth': 12,
#    'min_child_samples': 265,
#    'num_leaves': 124,
#    'reg_alpha': 0.6562946075310944,
#    'reg_lambda': 0.43132505643799623,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 264,
#   'train_time': 61.595705600004294,
#   'status': 'ok'},
#  {'loss': 0.22685840517348876,
#   'auc': 0.7731415948265112,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6730734766082036,
#    'is_unbalance': True,
#    'learning_rate': 0.057246115898255165,
#    'max_depth': 12,
#    'min_child_samples': 340,
#    'num_leaves': 108,
#    'reg_alpha': 0.7445101976937436,
#    'reg_lambda': 0.4960811651702217,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 265,
#   'train_time': 61.194759899997734,
#   'status': 'ok'},
#  {'loss': 0.22710609422623595,
#   'auc': 0.772893905773764,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6630958877771588,
#    'is_unbalance': True,
#    'learning_rate': 0.05913055091257491,
#    'max_depth': 10,
#    'min_child_samples': 365,
#    'num_leaves': 104,
#    'reg_alpha': 0.9487587037195044,
#    'reg_lambda': 0.5460595782877005,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 266,
#   'train_time': 58.4894370999973,
#   'status': 'ok'},
#  {'loss': 0.22691234942474547,
#   'auc': 0.7730876505752545,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6510047489708026,
#    'is_unbalance': True,
#    'learning_rate': 0.05160314481460889,
#    'max_depth': 12,
#    'min_child_samples': 380,
#    'num_leaves': 115,
#    'reg_alpha': 0.9649622057298081,
#    'reg_lambda': 0.32178204228953866,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 267,
#   'train_time': 60.8332919000095,
#   'status': 'ok'},
#  {'loss': 0.22968398060250073,
#   'auc': 0.7703160193974993,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6752977897995242,
#    'is_unbalance': True,
#    'learning_rate': 0.03386051661985508,
#    'max_depth': 10,
#    'min_child_samples': 380,
#    'num_leaves': 116,
#    'reg_alpha': 0.9753924391247182,
#    'reg_lambda': 0.25429356451432983,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 268,
#   'train_time': 63.897326000005705,
#   'status': 'ok'},
#  {'loss': 0.22885509965683026,
#   'auc': 0.7711449003431697,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6524116071675344,
#    'is_unbalance': True,
#    'learning_rate': 0.03766886634946709,
#    'max_depth': 12,
#    'min_child_samples': 405,
#    'num_leaves': 108,
#    'reg_alpha': 0.9713185910346698,
#    'reg_lambda': 0.27348370362646846,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 269,
#   'train_time': 63.108362099999795,
#   'status': 'ok'},
#  {'loss': 0.22748374428214346,
#   'auc': 0.7725162557178565,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6508530838853023,
#    'is_unbalance': True,
#    'learning_rate': 0.054958009237618725,
#    'max_depth': 10,
#    'min_child_samples': 390,
#    'num_leaves': 112,
#    'reg_alpha': 0.9341163684832509,
#    'reg_lambda': 0.22803656831879426,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 270,
#   'train_time': 58.84700999999768,
#   'status': 'ok'},
#  {'loss': 0.22766106347706772,
#   'auc': 0.7723389365229323,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6059931376955827,
#    'is_unbalance': True,
#    'learning_rate': 0.043113011087864674,
#    'max_depth': 12,
#    'min_child_samples': 430,
#    'num_leaves': 113,
#    'reg_alpha': 0.8077006213612656,
#    'reg_lambda': 0.11748902410021755,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 271,
#   'train_time': 68.79724569999962,
#   'status': 'ok'},
#  {'loss': 0.2317476086191056,
#   'auc': 0.7682523913808944,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.639299453949057,
#    'is_unbalance': True,
#    'learning_rate': 0.027694315603062084,
#    'max_depth': 10,
#    'min_child_samples': 465,
#    'num_leaves': 115,
#    'reg_alpha': 0.8259156358674076,
#    'reg_lambda': 0.3351138718084575,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 272,
#   'train_time': 65.32968249999976,
#   'status': 'ok'},
#  {'loss': 0.2271484660652432,
#   'auc': 0.7728515339347568,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.621638749865837,
#    'is_unbalance': True,
#    'learning_rate': 0.04606070455836266,
#    'max_depth': 12,
#    'min_child_samples': 345,
#    'num_leaves': 134,
#    'reg_alpha': 0.8669181774094219,
#    'reg_lambda': 0.16883104182008485,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 273,
#   'train_time': 62.61369640000339,
#   'status': 'ok'},
#  {'loss': 0.22965926789351787,
#   'auc': 0.7703407321064821,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6713265998373368,
#    'is_unbalance': True,
#    'learning_rate': 0.03216317231198534,
#    'max_depth': 12,
#    'min_child_samples': 400,
#    'num_leaves': 121,
#    'reg_alpha': 0.7238048468385697,
#    'reg_lambda': 0.38387330016133137,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 274,
#   'train_time': 67.20878659999289,
#   'status': 'ok'},
#  {'loss': 0.228276263544404,
#   'auc': 0.771723736455596,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6614038556936966,
#    'is_unbalance': True,
#    'learning_rate': 0.050390863775143284,
#    'max_depth': 8,
#    'min_child_samples': 360,
#    'num_leaves': 109,
#    'reg_alpha': 0.9975930170393339,
#    'reg_lambda': 0.3144065702304342,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 275,
#   'train_time': 55.81576149999455,
#   'status': 'ok'},
#  {'loss': 0.2294127431482783,
#   'auc': 0.7705872568517217,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.7048772665137131,
#    'is_unbalance': True,
#    'learning_rate': 0.03892528019587623,
#    'max_depth': 10,
#    'min_child_samples': 420,
#    'num_leaves': 95,
#    'reg_alpha': 0.7834804135204644,
#    'reg_lambda': 0.40681460320053486,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 276,
#   'train_time': 63.30683850000787,
#   'status': 'ok'},
#  {'loss': 0.22706396202410517,
#   'auc': 0.7729360379758948,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6859246470527365,
#    'is_unbalance': True,
#    'learning_rate': 0.05305203309420463,
#    'max_depth': 12,
#    'min_child_samples': 375,
#    'num_leaves': 118,
#    'reg_alpha': 0.9213469958837037,
#    'reg_lambda': 0.3617078140924555,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 277,
#   'train_time': 63.16421219999029,
#   'status': 'ok'},
#  {'loss': 0.22792691602343196,
#   'auc': 0.772073083976568,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.69173478602698,
#    'is_unbalance': True,
#    'learning_rate': 0.048855852655939634,
#    'max_depth': 10,
#    'min_child_samples': 445,
#    'num_leaves': 128,
#    'reg_alpha': 0.8369953563722436,
#    'reg_lambda': 0.4495505499879199,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 278,
#   'train_time': 60.08214020000014,
#   'status': 'ok'},
#  {'loss': 0.22824702800355845,
#   'auc': 0.7717529719964416,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6294302058987112,
#    'is_unbalance': True,
#    'learning_rate': 0.04061871365839545,
#    'max_depth': 12,
#    'min_child_samples': 340,
#    'num_leaves': 98,
#    'reg_alpha': 0.6724047521474762,
#    'reg_lambda': 0.18778656675742705,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 279,
#   'train_time': 60.62721550000424,
#   'status': 'ok'},
#  {'loss': 0.22701982213935257,
#   'auc': 0.7729801778606474,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6153212907747365,
#    'is_unbalance': True,
#    'learning_rate': 0.06194688716979221,
#    'max_depth': 12,
#    'min_child_samples': 325,
#    'num_leaves': 103,
#    'reg_alpha': 0.6210714624333626,
#    'reg_lambda': 0.5186193057838288,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 280,
#   'train_time': 59.79997330000333,
#   'status': 'ok'},
#  {'loss': 0.22714119893993123,
#   'auc': 0.7728588010600688,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.656996838502226,
#    'is_unbalance': True,
#    'learning_rate': 0.057744067576447754,
#    'max_depth': 10,
#    'min_child_samples': 410,
#    'num_leaves': 105,
#    'reg_alpha': 0.8823245294798985,
#    'reg_lambda': 0.4838752062223758,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 281,
#   'train_time': 58.33669660000305,
#   'status': 'ok'},
#  {'loss': 0.22860707365802035,
#   'auc': 0.7713929263419796,
#   'params': {'boosting_type': 'goss',
#    'colsample_bytree': 0.6460839489757596,
#    'is_unbalance': True,
#    'learning_rate': 0.036251235309704796,
#    'max_depth': 12,
#    'min_child_samples': 355,
#    'num_leaves': 139,
#    'reg_alpha': 0.7048254862192604,
#    'reg_lambda': 0.31229165898189576,
#    'subsample': 1.0,
#    'metrics': 'auc',
#    'verbose': -1},
#   'iteration': 282,
#   'train_time': 67.37378389999503,
#   'status': 'ok'}]
